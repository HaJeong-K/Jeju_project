# %% [markdown]
# # 2020 제주 여행 세부사항 만족도 평가 조사
# - 원래는 렌터카 등 교통이용 평가도 포함되어 있으나 DB문제로 인해 데이터를 얻을 수 없어서 뺌
# - 코로나 발생으로 일부 월 데이터 누락

# %% [markdown]
# ## 라이브러리

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 데이터 경로설정

# %%
DATA_PATH = '/content/drive/MyDrive/Colab Notebooks/jeju/'

# %% [markdown]
# ## 관광정보 만족도

# %%
tourinfo_2020 = pd.read_excel(DATA_PATH + 'plus/2020_관광정보서비스.xlsx',
                            skiprows=1,
                            skipfooter=1)
tourinfo_2020.head()
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족  BOT2(①+②)  \
# 0       [전체]        NaN  3351      0.9   4.5  34.2  47.9    12.5        5.3
# 1         구분     01-02월   919      0.2   1.6  18.9  58.2    21.0        1.8
# 2         구분     08-12월  2431      1.1   5.6  40.0  44.0     9.3        6.7
# 3         월별        01월   596      0.2   1.6  20.7  55.8    21.7        1.8
# 4         월별        02월   323      0.3   1.5  15.6  62.7    19.9        1.8
#
#    MID(③)  TOP2(④+⑤)  척도평균  100점평균
# 0    34.2       60.4  3.67   66.69
# 1    18.9       79.3  3.98   74.58
# 2    40.0       53.3  3.55   63.71
# 3    20.7       77.5  3.97   74.29
# 4    15.6       82.6  4.00   75.10

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '관광정보 사례수',
           'BOT2(①+②)' : '관광정보 불만족',
           'MID(③)' : '관광정보 보통',
           'TOP2(④+⑤)' : '관광정보 만족',
           '척도평균' : '관광정보 5점평균',
            '100점평균' : '관광정보 100점평균'
           }
tourinfo_2020 = tourinfo_2020.rename(columns = columns)
tourinfo_2020.head()
# Out:
#      분류    세부분류  관광정보 사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족  관광정보 불만족  \
# 0  [전체]     NaN      3351      0.9   4.5  34.2  47.9    12.5       5.3
# 1    구분  01-02월       919      0.2   1.6  18.9  58.2    21.0       1.8
# 2    구분  08-12월      2431      1.1   5.6  40.0  44.0     9.3       6.7
# 3    월별     01월       596      0.2   1.6  20.7  55.8    21.7       1.8
# 4    월별     02월       323      0.3   1.5  15.6  62.7    19.9       1.8
#
#    관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균
# 0     34.2     60.4       3.67        66.69
# 1     18.9     79.3       3.98        74.58
# 2     40.0     53.3       3.55        63.71
# 3     20.7     77.5       3.97        74.29
# 4     15.6     82.6       4.00        75.10

# %%
tourinfo_2020 = tourinfo_2020.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족'], axis = 1)
tourinfo_2020.head(2)
# Out:
#      분류    세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균
# 0  [전체]     NaN      3351       5.3     34.2     60.4       3.67        66.69
# 1    구분  01-02월       919       1.8     18.9     79.3       3.98        74.58

# %%
tourinfo_2020 = tourinfo_2020.iloc[3:10, :].reset_index(drop=True)
tourinfo_2020
# Out:
#    분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균
# 0  월별  01월       596       1.8     20.7     77.5       3.97        74.29
# 1  월별  02월       323       1.8     15.6     82.6       4.00        75.10
# 2  월별  08월       583       5.9     42.2     51.9       3.54        63.38
# 3  월별  09월       373       8.2     42.7     49.1       3.48        61.92
# 4  월별  10월       553       5.4     39.1     55.5       3.59        64.87
# 5  월별  11월       587       6.9     38.7     54.5       3.56        64.05
# 6  월별  12월       335       8.0     37.3     54.7       3.55        63.78

# %%
'''new_rows_2020 = pd.DataFrame([
    {'분류': '월별', '세부분류': '03월', '관광정보 사례수': np.nan, '관광정보 불만족': np.nan, '관광정보 보통': np.nan, '관광정보 만족': np.nan,
     '관광정보 5점평균': np.nan, '관광정보 100점평균': np.nan},
    {'분류': '월별', '세부분류': '04월', '관광정보 사례수': np.nan, '관광정보 불만족': np.nan, '관광정보 보통': np.nan, '관광정보 만족': np.nan,
     '관광정보 5점평균': np.nan, '관광정보 100점평균': np.nan},
    {'분류': '월별', '세부분류': '05월', '관광정보 사례수': np.nan, '관광정보 불만족': np.nan, '관광정보 보통': np.nan, '관광정보 만족': np.nan,
     '관광정보 5점평균': np.nan, '관광정보 100점평균': np.nan},
    {'분류': '월별', '세부분류': '06월', '관광정보 사례수': np.nan, '관광정보 불만족': np.nan, '관광정보 보통': np.nan, '관광정보 만족': np.nan,
     '관광정보 5점평균': np.nan, '관광정보 100점평균': np.nan},
    {'분류': '월별', '세부분류': '07월', '관광정보 사례수': np.nan, '관광정보 불만족': np.nan, '관광정보 보통': np.nan, '관광정보 만족': np.nan,
     '관광정보 5점평균': np.nan, '관광정보 100점평균': np.nan}
])

tourinfo_2020 = pd.concat([tourinfo_2020, new_rows_2020], axis=0)

# %%
'''tourinfo_2020 = tourinfo_2020.reset_index(drop=True)
tourinfo_2020
# Out:
#     분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균
# 0   월별  01월     596.0       1.8     20.7     77.5       3.97        74.29
# 1   월별  02월     323.0       1.8     15.6     82.6       4.00        75.10
# 2   월별  08월     583.0       5.9     42.2     51.9       3.54        63.38
# 3   월별  09월     373.0       8.2     42.7     49.1       3.48        61.92
# 4   월별  10월     553.0       5.4     39.1     55.5       3.59        64.87
# 5   월별  11월     587.0       6.9     38.7     54.5       3.56        64.05
# 6   월별  12월     335.0       8.0     37.3     54.7       3.55        63.78
# 7   월별  03월       NaN       NaN      NaN      NaN        NaN          NaN
# 8   월별  04월       NaN       NaN      NaN      NaN        NaN          NaN
# 9   월별  05월       NaN       NaN      NaN      NaN        NaN          NaN
# 10  월별  06월       NaN       NaN      NaN      NaN        NaN          NaN
# 11  월별  07월       NaN       NaN      NaN      NaN        NaN          NaN

# %%
'''
rows_to_move = tourinfo_2020.iloc[7:12]
tourinfo_2020 = tourinfo_2020.drop(tourinfo_2020.index[7:12])

desired_index = 2
tourinfo_2020 = tourinfo_2020.iloc[:desired_index].append(rows_to_move).append(tourinfo_2020.iloc[desired_index:]).reset_index(drop=True)

tourinfo_2020
'''
# Out:
# <ipython-input-24-4dbd0dd7b016>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tourinfo_2020 = tourinfo_2020.iloc[:desired_index].append(rows_to_move).append(tourinfo_2020.iloc[desired_index:]).reset_index(drop=True)
#     분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균
# 0   월별  01월     596.0       1.8     20.7     77.5       3.97        74.29
# 1   월별  02월     323.0       1.8     15.6     82.6       4.00        75.10
# 2   월별  03월       NaN       NaN      NaN      NaN        NaN          NaN
# 3   월별  04월       NaN       NaN      NaN      NaN        NaN          NaN
# 4   월별  05월       NaN       NaN      NaN      NaN        NaN          NaN
# 5   월별  06월       NaN       NaN      NaN      NaN        NaN          NaN
# 6   월별  07월       NaN       NaN      NaN      NaN        NaN          NaN
# 7   월별  08월     583.0       5.9     42.2     51.9       3.54        63.38
# ...

# %% [markdown]
# ## 관광지매력도 만족도

# %%
placecharm_2020 = pd.read_excel(DATA_PATH + 'plus/2020_관광지매력도.xlsx',
                            skiprows=1,
                            skipfooter=1)
placecharm_2020.head()
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족  BOT2(①+②)  \
# 0       [전체]        NaN  3421      0.7   2.0  15.0  46.4    35.9        2.7
# 1         구분     01-02월   921      0.1   1.1  11.9  37.5    49.4        1.2
# 2         구분     08-12월  2500      0.9   2.3  16.1  49.7    30.9        3.2
# 3         월별        01월   595      0.0   1.4  13.8  38.0    46.9        1.4
# 4         월별        02월   327      0.2   0.7   8.5  36.5    54.0        1.0
#
#    MID(③)  TOP2(④+⑤)  척도평균  100점평균
# 0    15.0       82.3  4.15   78.71
# 1    11.9       86.9  4.35   83.74
# 2    16.1       80.7  4.07   76.86
# 3    13.8       84.8  4.30   82.58
# 4     8.5       90.5  4.43   85.83

# %%
placecharm_2020 = placecharm_2020.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족'], axis = 1)
placecharm_2020.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  BOT2(①+②)  MID(③)  TOP2(④+⑤)  척도평균  100점평균
# 0       [전체]        NaN  3421        2.7    15.0       82.3  4.15   78.71
# 1         구분     01-02월   921        1.2    11.9       86.9  4.35   83.74

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '관광지매력 사례수',
           'BOT2(①+②)' : '관광지매력 불만족',
           'MID(③)' : '관광지매력 보통',
           'TOP2(④+⑤)' : '관광지매력 만족',
           '척도평균' : '관광지매력 5점평균',
            '100점평균' : '관광지매력 100점평균'
           }
placecharm_2020 = placecharm_2020.rename(columns = columns)
placecharm_2020.head()
# Out:
#      분류    세부분류  관광지매력 사례수  관광지매력 불만족  관광지매력 보통  관광지매력 만족  관광지매력 5점평균  \
# 0  [전체]     NaN       3421        2.7      15.0      82.3        4.15
# 1    구분  01-02월        921        1.2      11.9      86.9        4.35
# 2    구분  08-12월       2500        3.2      16.1      80.7        4.07
# 3    월별     01월        595        1.4      13.8      84.8        4.30
# 4    월별     02월        327        1.0       8.5      90.5        4.43
#
#    관광지매력 100점평균
# 0         78.71
# 1         83.74
# 2         76.86
# 3         82.58
# 4         85.83

# %%
placecharm_2020 = placecharm_2020.iloc[3:10, :].reset_index(drop=True)
placecharm_2020
# Out:
#    분류 세부분류  관광지매력 사례수  관광지매력 불만족  관광지매력 보통  관광지매력 만족  관광지매력 5점평균  관광지매력 100점평균
# 0  월별  01월        595        1.4      13.8      84.8        4.30         82.58
# 1  월별  02월        327        1.0       8.5      90.5        4.43         85.83
# 2  월별  08월        600        1.8      18.4      79.8        4.08         76.98
# 3  월별  09월        385        4.0      15.0      81.0        4.05         76.16
# 4  월별  10월        573        2.6      11.0      86.4        4.18         79.62
# 5  월별  11월        608        2.6      17.6      79.8        4.08         77.05
# 6  월별  12월        334        6.8      19.5      73.6        3.90         72.38

# %% [markdown]
# ## 교통정보 서비스

# %%
trafficinfo_2020 = pd.read_excel(DATA_PATH + 'plus/2020_교통정보서비스.xlsx',
                            skiprows=1,
                            skipfooter=1)
trafficinfo_2020.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족  BOT2(①+②)  \
# 0       [전체]        NaN  3275      1.6   7.0  33.2  47.5    10.7        8.6
# 1         구분     01-02월   899      0.4   3.1  26.3  52.6    17.5        3.6
#
#    MID(③)  TOP2(④+⑤)  척도평균  100점평균
# 0    33.2       58.3  3.59   64.72
# 1    26.3       70.1  3.84   70.88

# %%
trafficinfo_2020 = trafficinfo_2020.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족'], axis = 1)
trafficinfo_2020.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  BOT2(①+②)  MID(③)  TOP2(④+⑤)  척도평균  100점평균
# 0       [전체]        NaN  3275        8.6    33.2       58.3  3.59   64.72
# 1         구분     01-02월   899        3.6    26.3       70.1  3.84   70.88

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '교통정보 사례수',
           'BOT2(①+②)' : '교통정보 불만족',
           'MID(③)' : '교통정보 보통',
           'TOP2(④+⑤)' : '교통정보 만족',
           '척도평균' : '교통정보 5점평균',
            '100점평균' : '교통정보 100점평균'
           }
trafficinfo_2020 = trafficinfo_2020.rename(columns = columns)
trafficinfo_2020.head()
# Out:
#      분류    세부분류  교통정보 사례수  교통정보 불만족  교통정보 보통  교통정보 만족  교통정보 5점평균  교통정보 100점평균
# 0  [전체]     NaN      3275       8.6     33.2     58.3       3.59        64.72
# 1    구분  01-02월       899       3.6     26.3     70.1       3.84        70.88
# 2    구분  08-12월      2376      10.5     35.8     53.8       3.50        62.38
# 3    월별     01월       576       4.9     29.4     65.7       3.77        69.29
# 4    월별     02월       324       1.3     20.9     77.8       3.95        73.70

# %%
trafficinfo_2020 = trafficinfo_2020.iloc[3:10, :].reset_index(drop=True)
trafficinfo_2020
# Out:
#    분류 세부분류  교통정보 사례수  교통정보 불만족  교통정보 보통  교통정보 만족  교통정보 5점평균  교통정보 100점평균
# 0  월별  01월       576       4.9     29.4     65.7       3.77        69.29
# 1  월별  02월       324       1.3     20.9     77.8       3.95        73.70
# 2  월별  08월       574      11.2     36.4     52.4       3.48        62.03
# 3  월별  09월       364      10.4     33.9     55.7       3.52        62.96
# 4  월별  10월       547       9.4     35.5     55.1       3.52        62.98
# 5  월별  11월       569      10.1     35.9     53.9       3.49        62.30
# 6  월별  12월       322      11.5     36.9     51.7       3.46        61.51

# %% [markdown]
# ## 방문관광지 편의성 만족도

# %%
conv_2020 = pd.read_excel(DATA_PATH + 'plus/2020_방문관광지편의성.xlsx',
                            skiprows=1,
                            skipfooter=1)
conv_2020.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족  BOT2(①+②)  \
# 0       [전체]        NaN  3420      1.0   3.5  26.7  49.9    18.8        4.5
# 1         구분     01-02월   922      0.3   1.8  14.5  46.5    36.9        2.1
#
#    MID(③)  TOP2(④+⑤)  척도평균  100점평균
# 0    26.7       68.7  3.82   70.50
# 1    14.5       83.4  4.18   79.48

# %%
conv_2020 = conv_2020.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족'], axis = 1)
conv_2020.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  BOT2(①+②)  MID(③)  TOP2(④+⑤)  척도평균  100점평균
# 0       [전체]        NaN  3420        4.5    26.7       68.7  3.82   70.50
# 1         구분     01-02월   922        2.1    14.5       83.4  4.18   79.48

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '관광지편의성 사례수',
           'BOT2(①+②)' : '관광지편의성 불만족',
           'MID(③)' : '관광지편의성 보통',
           'TOP2(④+⑤)' : '관광지편의성 만족',
           '척도평균' : '관광지편의성 5점평균',
            '100점평균' : '관광지편의성 100점평균'
           }
conv_2020 = conv_2020.rename(columns = columns)
conv_2020.head()
# Out:
#      분류    세부분류  관광지편의성 사례수  관광지편의성 불만족  관광지편의성 보통  관광지편의성 만족  관광지편의성 5점평균  \
# 0  [전체]     NaN        3420         4.5       26.7       68.7         3.82
# 1    구분  01-02월         922         2.1       14.5       83.4         4.18
# 2    구분  08-12월        2498         5.4       31.3       63.3         3.69
# 3    월별     01월         598         2.5       16.5       81.0         4.12
# 4    월별     02월         325         1.5       10.7       87.8         4.28
#
#    관광지편의성 100점평균
# 0          70.50
# 1          79.48
# 2          67.18
# 3          78.05
# 4          82.12

# %%
conv_2020 = conv_2020.iloc[3:10, :].reset_index(drop=True)
conv_2020
# Out:
#    분류 세부분류  관광지편의성 사례수  관광지편의성 불만족  관광지편의성 보통  관광지편의성 만족  관광지편의성 5점평균  \
# 0  월별  01월         598         2.5       16.5       81.0         4.12
# 1  월별  02월         325         1.5       10.7       87.8         4.28
# 2  월별  08월         601         5.5       29.6       64.9         3.68
# 3  월별  09월         381         7.9       30.7       61.4         3.65
# 4  월별  10월         575         3.0       28.8       68.2         3.78
# 5  월별  11월         607         4.9       33.4       61.7         3.67
# 6  월별  12월         334         7.6       35.1       57.2         3.61
#
#    관광지편의성 100점평균
# 0          78.05
# 1          82.12
# 2          67.12
# 3          66.17
# 4          69.55
# 5          66.72
# 6          65.21

# %% [markdown]
# ## 쇼핑 만족도

# %%
shopping_2020 = pd.read_excel(DATA_PATH + 'plus/2020_쇼핑.xlsx',
                            skiprows=1,
                            skipfooter=1)
shopping_2020.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족  BOT2(①+②)  \
# 0       [전체]        NaN  3017      1.0   8.2  38.9  40.3    11.6        9.2
# 1         구분     01-02월   870      0.0   2.9  21.5  50.8    24.8        2.9
#
#    MID(③)  TOP2(④+⑤)  척도평균  100점평균
# 0    38.9       51.9  3.53   63.34
# 1    21.5       75.6  3.98   74.38

# %%
shopping_2020 = shopping_2020.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족'], axis = 1)
shopping_2020.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  BOT2(①+②)  MID(③)  TOP2(④+⑤)  척도평균  100점평균
# 0       [전체]        NaN  3017        9.2    38.9       51.9  3.53   63.34
# 1         구분     01-02월   870        2.9    21.5       75.6  3.98   74.38

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '쇼핑 사례수',
           'BOT2(①+②)' : '쇼핑 불만족',
           'MID(③)' : '쇼핑 보통',
           'TOP2(④+⑤)' : '쇼핑 만족',
           '척도평균' : '쇼핑 5점평균',
            '100점평균' : '쇼핑 100점평균'
           }
shopping_2020 = shopping_2020.rename(columns = columns)
shopping_2020.head()
# Out:
#      분류    세부분류  쇼핑 사례수  쇼핑 불만족  쇼핑 보통  쇼핑 만족  쇼핑 5점평균  쇼핑 100점평균
# 0  [전체]     NaN    3017     9.2   38.9   51.9     3.53      63.34
# 1    구분  01-02월     870     2.9   21.5   75.6     3.98      74.38
# 2    구분  08-12월    2146    11.7   46.0   42.3     3.35      58.86
# 3    월별     01월     570     3.5   23.5   73.0     3.93      73.23
# 4    월별     02월     300     1.6   17.9   80.5     4.06      76.55

# %%
shopping_2020 = shopping_2020.iloc[3:10, :].reset_index(drop=True)
shopping_2020
# Out:
#    분류 세부분류  쇼핑 사례수  쇼핑 불만족  쇼핑 보통  쇼핑 만족  쇼핑 5점평균  쇼핑 100점평균
# 0  월별  01월     570     3.5   23.5   73.0     3.93      73.23
# 1  월별  02월     300     1.6   17.9   80.5     4.06      76.55
# 2  월별  08월     543     9.1   47.5   43.4     3.38      59.40
# 3  월별  09월     332    13.9   45.6   40.5     3.28      57.06
# 4  월별  10월     485    12.6   44.3   43.1     3.37      59.19
# 5  월별  11월     503    12.7   46.6   40.7     3.34      58.48
# 6  월별  12월     283    11.2   45.1   43.7     3.40      60.10

# %% [markdown]
# ## 숙박시설 만족도

# %%
accom_2020 = pd.read_excel(DATA_PATH + 'plus/2020_숙박시설.xlsx',
                            skiprows=1,
                            skipfooter=1)
accom_2020.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족  BOT2(①+②)  \
# 0       [전체]        NaN  3220      0.8   2.6  15.2  54.5    27.0        3.4
# 1         구분     01-02월   863      0.2   0.3   8.5  51.4    39.6        0.6
#
#    MID(③)  TOP2(④+⑤)  척도평균  100점평균
# 0    15.2       81.5  4.04   76.08
# 1     8.5       90.9  4.30   82.42

# %%
accom_2020 = accom_2020.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족'], axis = 1)
accom_2020.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  BOT2(①+②)  MID(③)  TOP2(④+⑤)  척도평균  100점평균
# 0       [전체]        NaN  3220        3.4    15.2       81.5  4.04   76.08
# 1         구분     01-02월   863        0.6     8.5       90.9  4.30   82.42

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '숙박 사례수',
           'BOT2(①+②)' : '숙박 불만족',
           'MID(③)' : '숙박 보통',
           'TOP2(④+⑤)' : '숙박 만족',
           '척도평균' : '숙박 5점평균',
            '100점평균' : '숙박 100점평균'
           }
accom_2020 = accom_2020.rename(columns = columns)
accom_2020.head(2)
# Out:
#      분류    세부분류  숙박 사례수  숙박 불만족  숙박 보통  숙박 만족  숙박 5점평균  숙박 100점평균
# 0  [전체]     NaN    3220     3.4   15.2   81.5     4.04      76.08
# 1    구분  01-02월     863     0.6    8.5   90.9     4.30      82.42

# %%
accom_2020 = accom_2020.iloc[3:10, :].reset_index(drop=True)
accom_2020
# Out:
#    분류 세부분류  숙박 사례수  숙박 불만족  숙박 보통  숙박 만족  숙박 5점평균  숙박 100점평균
# 0  월별  01월     547     0.7    9.6   89.6     4.28      82.06
# 1  월별  02월     316     0.3    6.6   93.2     4.32      83.05
# 2  월별  08월     570     3.6   19.2   77.2     3.96      73.99
# 3  월별  09월     358     4.3   20.0   75.6     3.92      73.08
# 4  월별  10월     537     3.2   17.4   79.4     3.99      74.73
# 5  월별  11월     572     5.6   12.6   81.8     3.97      74.13
# 6  월별  12월     319     5.7   21.4   72.9     3.87      71.74

# %% [markdown]
# ## 여행경비 만족도

# %%
budget_2020 = pd.read_excel(DATA_PATH + 'plus/2020_여행경비.xlsx',
                            skiprows=1,
                            skipfooter=1)
budget_2020.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족  BOT2(①+②)  \
# 0       [전체]        NaN  3444      8.7  26.5  35.6  22.8     6.4       35.2
# 1         구분     01-02월   927      4.3  14.8  36.9  33.9    10.1       19.1
#
#    MID(③)  TOP2(④+⑤)  척도평균  100점평균
# 0    35.6       29.2  2.92   47.97
# 1    36.9       44.1  3.31   57.71

# %%
budget_2020 = budget_2020.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족'], axis = 1)
budget_2020.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  BOT2(①+②)  MID(③)  TOP2(④+⑤)  척도평균  100점평균
# 0       [전체]        NaN  3444       35.2    35.6       29.2  2.92   47.97
# 1         구분     01-02월   927       19.1    36.9       44.1  3.31   57.71

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '여행경비 사례수',
           'BOT2(①+②)' : '여행경비 불만족',
           'MID(③)' : '여행경비 보통',
           'TOP2(④+⑤)' : '여행경비 만족',
           '척도평균' : '여행경비 5점평균',
            '100점평균' : '여행경비 100점평균'
           }
budget_2020 = budget_2020.rename(columns = columns)
budget_2020.head(2)
# Out:
#      분류    세부분류  여행경비 사례수  여행경비 불만족  여행경비 보통  여행경비 만족  여행경비 5점평균  여행경비 100점평균
# 0  [전체]     NaN      3444      35.2     35.6     29.2       2.92        47.97
# 1    구분  01-02월       927      19.1     36.9     44.1       3.31        57.71

# %%
budget_2020 = budget_2020.iloc[3:10, :].reset_index(drop=True)
budget_2020
# Out:
#    분류 세부분류  여행경비 사례수  여행경비 불만족  여행경비 보통  여행경비 만족  여행경비 5점평균  여행경비 100점평균
# 0  월별  01월       600      21.6     37.2     41.2       3.25        56.26
# 1  월별  02월       327      14.4     36.3     49.4       3.42        60.39
# 2  월별  08월       604      45.3     33.4     21.4       2.67        41.86
# 3  월별  09월       392      44.5     35.8     19.7       2.66        41.59
# 4  월별  10월       580      39.5     35.5     25.0       2.82        45.59
# 5  월별  11월       603      41.1     35.4     23.6       2.78        44.55
# 6  월별  12월       339      32.5     36.4     31.1       2.99        49.70

# %% [markdown]
# ## 음식 만족도

# %%
food_2020 = pd.read_excel(DATA_PATH + 'plus/2020_음식.xlsx',
                            skiprows=1,
                            skipfooter=1)
food_2020.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족  BOT2(①+②)  \
# 0       [전체]        NaN  3429      1.1   4.3  21.5  51.3    21.8        5.4
# 1         구분     01-02월   909      0.5   2.6  12.7  50.2    34.1        3.0
#
#    MID(③)  TOP2(④+⑤)  척도평균  100점평균
# 0    21.5       73.0  3.88   72.06
# 1    12.7       84.3  4.15   78.72

# %%
food_2020 = food_2020.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족'], axis = 1)
food_2020.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  BOT2(①+②)  MID(③)  TOP2(④+⑤)  척도평균  100점평균
# 0       [전체]        NaN  3429        5.4    21.5       73.0  3.88   72.06
# 1         구분     01-02월   909        3.0    12.7       84.3  4.15   78.72

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '음식 사례수',
           'BOT2(①+②)' : '음식 불만족',
           'MID(③)' : '음식 보통',
           'TOP2(④+⑤)' : '음식 만족',
           '척도평균' : '음식 5점평균',
            '100점평균' : '음식 100점평균'
           }
food_2020 = food_2020.rename(columns = columns)
food_2020.head(2)
# Out:
#      분류    세부분류  음식 사례수  음식 불만족  음식 보통  음식 만족  음식 5점평균  음식 100점평균
# 0  [전체]     NaN    3429     5.4   21.5   73.0     3.88      72.06
# 1    구분  01-02월     909     3.0   12.7   84.3     4.15      78.72

# %%
food_2020 = food_2020.iloc[3:10, :].reset_index(drop=True)
food_2020
# Out:
#    분류 세부분류  음식 사례수  음식 불만족  음식 보통  음식 만족  음식 5점평균  음식 100점평균
# 0  월별  01월     584     3.5   13.7   82.8     4.13      78.32
# 1  월별  02월     325     2.2   10.8   86.9     4.18      79.43
# 2  월별  08월     612     6.2   23.4   70.4     3.81      70.18
# 3  월별  09월     391     5.9   26.1   67.9     3.78      69.56
# 4  월별  10월     575     5.0   25.2   69.8     3.81      70.30
# 5  월별  11월     605     6.3   25.7   68.1     3.76      69.05
# 6  월별  12월     337     9.0   23.1   67.9     3.75      68.83

# %% [markdown]
# ## 제주도 내 대중교통 만족도

# %%
pt_2020 = pd.read_excel(DATA_PATH + 'plus/2020_제주도내대중교통.xlsx',
                            skiprows=1,
                            skipfooter=1)
pt_2020.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족  BOT2(①+②)  \
# 0       [전체]        NaN  1053      6.3  17.0  37.0  30.7     9.0       23.3
# 1         구분     01-02월   201      7.7  12.5  45.5  23.6    10.8       20.1
#
#    MID(③)  TOP2(④+⑤)  척도평균  100점평균
# 0    37.0       39.7  3.19   54.80
# 1    45.5       34.4  3.17   54.35

# %%
pt_2020 = pt_2020.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족'], axis = 1)
pt_2020.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  BOT2(①+②)  MID(③)  TOP2(④+⑤)  척도평균  100점평균
# 0       [전체]        NaN  1053       23.3    37.0       39.7  3.19   54.80
# 1         구분     01-02월   201       20.1    45.5       34.4  3.17   54.35

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '대중교통 사례수',
           'BOT2(①+②)' : '대중교통 불만족',
           'MID(③)' : '대중교통 보통',
           'TOP2(④+⑤)' : '대중교통 만족',
           '척도평균' : '대중교통 5점평균',
            '100점평균' : '대중교통 100점평균'
           }
pt_2020 = pt_2020.rename(columns = columns)
pt_2020.head(2)
# Out:
#      분류    세부분류  대중교통 사례수  대중교통 불만족  대중교통 보통  대중교통 만족  대중교통 5점평균  대중교통 100점평균
# 0  [전체]     NaN      1053      23.3     37.0     39.7       3.19        54.80
# 1    구분  01-02월       201      20.1     45.5     34.4       3.17        54.35

# %%
pt_2020 = pt_2020.iloc[3:10, :].reset_index(drop=True)
pt_2020
# Out:
#    분류 세부분류  대중교통 사례수  대중교통 불만족  대중교통 보통  대중교통 만족  대중교통 5점평균  대중교통 100점평균
# 0  월별  01월       153      22.2     44.3     33.5       3.12        53.11
# 1  월별  02월        49      13.7     49.4     36.9       3.33        58.24
# 2  월별  08월       199      25.5     32.1     42.4       3.21        55.15
# 3  월별  09월       138      21.9     41.3     36.8       3.16        54.02
# 4  월별  10월       193      27.4     31.6     41.0       3.12        53.12
# 5  월별  11월       196      21.3     37.3     41.4       3.26        56.41
# 6  월별  12월       125      23.1     34.4     42.5       3.24        55.91

# %% [markdown]
# ## 지역주민 친절 만족도

# %%
kind_2020 = pd.read_excel(DATA_PATH + 'plus/2020_지역주민친절.xlsx',
                            skiprows=1,
                            skipfooter=1)
kind_2020.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족  BOT2(①+②)  \
# 0       [전체]        NaN  3368      2.4   5.4  37.8  40.8    13.6        7.8
# 1         구분     01-02월   922      0.8   3.2  20.9  55.1    20.0        4.0
#
#    MID(③)  TOP2(④+⑤)  척도평균  100점평균
# 0    37.8       54.4  3.58   64.43
# 1    20.9       75.1  3.90   72.55

# %%
kind_2020 = kind_2020.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족'], axis = 1)
kind_2020.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  BOT2(①+②)  MID(③)  TOP2(④+⑤)  척도평균  100점평균
# 0       [전체]        NaN  3368        7.8    37.8       54.4  3.58   64.43
# 1         구분     01-02월   922        4.0    20.9       75.1  3.90   72.55

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '주민친절 사례수',
           'BOT2(①+②)' : '주민친절 불만족',
           'MID(③)' : '주민친절 보통',
           'TOP2(④+⑤)' : '주민친절 만족',
           '척도평균' : '주민친절 5점평균',
            '100점평균' : '주민친절 100점평균'
           }
kind_2020 = kind_2020.rename(columns = columns)
kind_2020.head(2)
# Out:
#      분류    세부분류  주민친절 사례수  주민친절 불만족  주민친절 보통  주민친절 만족  주민친절 5점평균  주민친절 100점평균
# 0  [전체]     NaN      3368       7.8     37.8     54.4       3.58        64.43
# 1    구분  01-02월       922       4.0     20.9     75.1       3.90        72.55

# %%
kind_2020 = kind_2020.iloc[3:10, :].reset_index(drop=True)
kind_2020
# Out:
#    분류 세부분류  주민친절 사례수  주민친절 불만족  주민친절 보통  주민친절 만족  주민친절 5점평균  주민친절 100점평균
# 0  월별  01월       597       4.8     22.1     73.1       3.86        71.57
# 1  월별  02월       325       2.7     18.6     78.7       3.97        74.34
# 2  월별  08월       591       9.6     42.3     48.1       3.47        61.75
# 3  월별  09월       376       9.6     48.7     41.7       3.39        59.63
# 4  월별  10월       552       9.4     41.9     48.7       3.48        61.97
# 5  월별  11월       592       7.5     47.0     45.5       3.46        61.57
# 6  월별  12월       334      11.2     41.2     47.6       3.45        61.35

# %% [markdown]
# ## 치안 만족도

# %%
safety_2020 = pd.read_excel(DATA_PATH + 'plus/2020_치안.xlsx',
                            skiprows=1,
                            skipfooter=1)
safety_2020.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족  BOT2(①+②)  \
# 0       [전체]        NaN  3447      0.9   2.9  24.2  51.1    20.9        3.8
# 1         구분     01-02월   924      0.3   0.8  14.5  62.4    22.0        1.0
#
#    MID(③)  TOP2(④+⑤)  척도평균  100점평균
# 0    24.2       72.0  3.88   72.03
# 1    14.5       84.4  4.05   76.28

# %%
safety_2020 = safety_2020.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족'], axis = 1)
safety_2020.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  BOT2(①+②)  MID(③)  TOP2(④+⑤)  척도평균  100점평균
# 0       [전체]        NaN  3447        3.8    24.2       72.0  3.88   72.03
# 1         구분     01-02월   924        1.0    14.5       84.4  4.05   76.28

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '치안 사례수',
           'BOT2(①+②)' : '치안 불만족',
           'MID(③)' : '치안 보통',
           'TOP2(④+⑤)' : '치안 만족',
           '척도평균' : '치안 5점평균',
            '100점평균' : '치안 100점평균'
           }
safety_2020 = safety_2020.rename(columns = columns)
safety_2020.head(2)
# Out:
#      분류    세부분류  치안 사례수  치안 불만족  치안 보통  치안 만족  치안 5점평균  치안 100점평균
# 0  [전체]     NaN    3447     3.8   24.2   72.0     3.88      72.03
# 1    구분  01-02월     924     1.0   14.5   84.4     4.05      76.28

# %%
safety_2020 = safety_2020.iloc[3:10, :].reset_index(drop=True)
safety_2020
# Out:
#    분류 세부분류  치안 사례수  치안 불만족  치안 보통  치안 만족  치안 5점평균  치안 100점평균
# 0  월별  01월     598     1.3   16.1   82.6     4.03      75.65
# 1  월별  02월     327     0.5   11.7   87.8     4.10      77.44
# 2  월별  08월     608     4.5   29.1   66.4     3.79      69.84
# 3  월별  09월     392     5.1   33.1   61.8     3.74      68.42
# 4  월별  10월     576     4.2   24.9   70.9     3.89      72.36
# 5  월별  11월     608     4.7   27.4   67.9     3.83      70.77
# 6  월별  12월     338     6.3   24.6   69.0     3.81      70.24

# %% [markdown]
# ## 통합

# %%
re = pd.merge(tourinfo_2020, placecharm_2020, on=['분류', '세부분류'])

# %%
re1 = pd.merge(re, trafficinfo_2020, on=['분류', '세부분류'])
re1.head(2)
# Out:
#    분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균  \
# 0  월별  01월       596       1.8     20.7     77.5       3.97        74.29
# 1  월별  02월       323       1.8     15.6     82.6       4.00        75.10
#
#    관광지매력 사례수  관광지매력 불만족  관광지매력 보통  관광지매력 만족  관광지매력 5점평균  관광지매력 100점평균  \
# 0        595        1.4      13.8      84.8        4.30         82.58
# 1        327        1.0       8.5      90.5        4.43         85.83
#
#    교통정보 사례수  교통정보 불만족  교통정보 보통  교통정보 만족  교통정보 5점평균  교통정보 100점평균
# 0       576       4.9     29.4     65.7       3.77        69.29
# 1       324       1.3     20.9     77.8       3.95        73.70

# %%
re2 = pd.merge(re1, conv_2020, on=['분류', '세부분류'])
re2.head(2)
# Out:
#    분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균  \
# 0  월별  01월       596       1.8     20.7     77.5       3.97        74.29
# 1  월별  02월       323       1.8     15.6     82.6       4.00        75.10
#
#    관광지매력 사례수  관광지매력 불만족  ...  교통정보 보통  교통정보 만족  교통정보 5점평균  교통정보 100점평균  \
# 0        595        1.4  ...     29.4     65.7       3.77        69.29
# 1        327        1.0  ...     20.9     77.8       3.95        73.70
#
#    관광지편의성 사례수  관광지편의성 불만족  관광지편의성 보통  관광지편의성 만족  관광지편의성 5점평균  관광지편의성 100점평균
# 0         598         2.5       16.5       81.0         4.12          78.05
# 1         325         1.5       10.7       87.8         4.28          82.12
#
# [2 rows x 26 columns]

# %%
re3 = pd.merge(re2, shopping_2020, on=['분류', '세부분류'])
re3
# Out:
#    분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균  \
# 0  월별  01월       596       1.8     20.7     77.5       3.97        74.29
# 1  월별  02월       323       1.8     15.6     82.6       4.00        75.10
# 2  월별  08월       583       5.9     42.2     51.9       3.54        63.38
# 3  월별  09월       373       8.2     42.7     49.1       3.48        61.92
# 4  월별  10월       553       5.4     39.1     55.5       3.59        64.87
# 5  월별  11월       587       6.9     38.7     54.5       3.56        64.05
# 6  월별  12월       335       8.0     37.3     54.7       3.55        63.78
#
#    관광지매력 사례수  관광지매력 불만족  ...  관광지편의성 보통  관광지편의성 만족  관광지편의성 5점평균  \
# 0        595        1.4  ...       16.5       81.0         4.12
# 1        327        1.0  ...       10.7       87.8         4.28
# 2        600        1.8  ...       29.6       64.9         3.68
# 3        385        4.0  ...       30.7       61.4         3.65
# ...

# %%
re4 = pd.merge(re3, accom_2020, on=['분류', '세부분류'])
re4.head(2)
# Out:
#    분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균  \
# 0  월별  01월       596       1.8     20.7     77.5       3.97        74.29
# 1  월별  02월       323       1.8     15.6     82.6       4.00        75.10
#
#    관광지매력 사례수  관광지매력 불만족  ...  쇼핑 보통  쇼핑 만족  쇼핑 5점평균  쇼핑 100점평균  숙박 사례수  \
# 0        595        1.4  ...   23.5   73.0     3.93      73.23     547
# 1        327        1.0  ...   17.9   80.5     4.06      76.55     316
#
#    숙박 불만족  숙박 보통  숙박 만족  숙박 5점평균  숙박 100점평균
# 0     0.7    9.6   89.6     4.28      82.06
# 1     0.3    6.6   93.2     4.32      83.05
#
# [2 rows x 38 columns]

# %%
re5 = pd.merge(re4, budget_2020, on=['분류', '세부분류'])
re5.head(2)
# Out:
#    분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균  \
# 0  월별  01월       596       1.8     20.7     77.5       3.97        74.29
# 1  월별  02월       323       1.8     15.6     82.6       4.00        75.10
#
#    관광지매력 사례수  관광지매력 불만족  ...  숙박 보통  숙박 만족  숙박 5점평균  숙박 100점평균  여행경비 사례수  \
# 0        595        1.4  ...    9.6   89.6     4.28      82.06       600
# 1        327        1.0  ...    6.6   93.2     4.32      83.05       327
#
#    여행경비 불만족  여행경비 보통  여행경비 만족  여행경비 5점평균  여행경비 100점평균
# 0      21.6     37.2     41.2       3.25        56.26
# 1      14.4     36.3     49.4       3.42        60.39
#
# [2 rows x 44 columns]

# %%
re6 = pd.merge(re5, food_2020, on=['분류', '세부분류'])
re6.head(2)
# Out:
#    분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균  \
# 0  월별  01월       596       1.8     20.7     77.5       3.97        74.29
# 1  월별  02월       323       1.8     15.6     82.6       4.00        75.10
#
#    관광지매력 사례수  관광지매력 불만족  ...  여행경비 보통  여행경비 만족  여행경비 5점평균  여행경비 100점평균  \
# 0        595        1.4  ...     37.2     41.2       3.25        56.26
# 1        327        1.0  ...     36.3     49.4       3.42        60.39
#
#    음식 사례수  음식 불만족  음식 보통  음식 만족  음식 5점평균  음식 100점평균
# 0     584     3.5   13.7   82.8     4.13      78.32
# 1     325     2.2   10.8   86.9     4.18      79.43
#
# [2 rows x 50 columns]

# %%
re7 = pd.merge(re6, pt_2020, on=['분류', '세부분류'])
re7.head(2)
# Out:
#    분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균  \
# 0  월별  01월       596       1.8     20.7     77.5       3.97        74.29
# 1  월별  02월       323       1.8     15.6     82.6       4.00        75.10
#
#    관광지매력 사례수  관광지매력 불만족  ...  음식 보통  음식 만족  음식 5점평균  음식 100점평균  대중교통 사례수  \
# 0        595        1.4  ...   13.7   82.8     4.13      78.32       153
# 1        327        1.0  ...   10.8   86.9     4.18      79.43        49
#
#    대중교통 불만족  대중교통 보통  대중교통 만족  대중교통 5점평균  대중교통 100점평균
# 0      22.2     44.3     33.5       3.12        53.11
# 1      13.7     49.4     36.9       3.33        58.24
#
# [2 rows x 56 columns]

# %%
re8 = pd.merge(re7, kind_2020, on=['분류', '세부분류'])
re8.head(2)
# Out:
#    분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균  \
# 0  월별  01월       596       1.8     20.7     77.5       3.97        74.29
# 1  월별  02월       323       1.8     15.6     82.6       4.00        75.10
#
#    관광지매력 사례수  관광지매력 불만족  ...  대중교통 보통  대중교통 만족  대중교통 5점평균  대중교통 100점평균  \
# 0        595        1.4  ...     44.3     33.5       3.12        53.11
# 1        327        1.0  ...     49.4     36.9       3.33        58.24
#
#    주민친절 사례수  주민친절 불만족  주민친절 보통  주민친절 만족  주민친절 5점평균  주민친절 100점평균
# 0       597       4.8     22.1     73.1       3.86        71.57
# 1       325       2.7     18.6     78.7       3.97        74.34
#
# [2 rows x 62 columns]

# %%
result_2020 = pd.merge(re8, safety_2020, on=['분류', '세부분류'])
result_2020.head(2)
# Out:
#    분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균  \
# 0  월별  01월       596       1.8     20.7     77.5       3.97        74.29
# 1  월별  02월       323       1.8     15.6     82.6       4.00        75.10
#
#    관광지매력 사례수  관광지매력 불만족  ...  주민친절 보통  주민친절 만족  주민친절 5점평균  주민친절 100점평균  \
# 0        595        1.4  ...     22.1     73.1       3.86        71.57
# 1        327        1.0  ...     18.6     78.7       3.97        74.34
#
#    치안 사례수  치안 불만족  치안 보통  치안 만족  치안 5점평균  치안 100점평균
# 0     598     1.3   16.1   82.6     4.03      75.65
# 1     327     0.5   11.7   87.8     4.10      77.44
#
# [2 rows x 68 columns]

# %%
result_2020.to_csv("result_2020.csv", index = True)
