# %% [markdown]
# # 2019 제주 여행 세부사항 만족도 평가 조사
# - 원래는 렌터카 등 교통이용 평가도 포함되어 있으나 DB문제로 인해 데이터를 얻을 수 없어서 뺌
# - 해당없음 선택지의 경우 년도마다 있고 없고 차이가 있어서 제외

# %% [markdown]
# ## 라이브러리

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 데이터 경로설정

# %%
DATA_PATH = '/content/drive/MyDrive/Colab Notebooks/jeju/'

# %% [markdown]
# ## 관광정보 만족도

# %%
tourinfo_2019 = pd.read_excel(DATA_PATH + 'plus/2019_관광정보서비스.xlsx',
                            skiprows=1,
                            skipfooter=1)
tourinfo_2019.head()
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족  해당없음  ①+②  \
# 0       [전체]        NaN  6133      0.1   1.1  12.4  54.1    31.9   0.5  1.1
# 1         월별        01월   463      0.0   0.2   4.0  55.8    39.4   0.5  0.2
# 2         월별        02월   452      0.0   0.5   2.1  51.8    45.3   0.2  0.5
# 3         월별        03월   470      0.0   1.6   6.0  53.7    38.1   0.5  1.6
# 4         월별        04월   524      0.2   0.0   4.4  53.2    41.9   0.2  0.2
#
#       ③   ④+⑤  해당없음.1  [5점 평균]  [100점 평균]
# 0  12.4  86.0     0.5     4.17      79.32
# 1   4.0  95.2     0.5     4.35      83.76
# 2   2.1  97.1     0.2     4.42      85.57
# 3   6.0  91.8     0.5     4.29      82.26
# 4   4.4  95.1     0.2     4.37      84.24

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '관광정보 사례수',
           '①+②' : '관광정보 불만족',
           '③' : '관광정보 보통',
           '④+⑤' : '관광정보 만족',
           '[5점 평균]' : '관광정보 5점평균',
            '[100점 평균]' : '관광정보 100점평균'
           }
tourinfo_2019 = tourinfo_2019.rename(columns = columns)
tourinfo_2019.head()
# Out:
#      분류 세부분류  관광정보 사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족  해당없음  관광정보 불만족  \
# 0  [전체]  NaN      6133      0.1   1.1  12.4  54.1    31.9   0.5       1.1
# 1    월별  01월       463      0.0   0.2   4.0  55.8    39.4   0.5       0.2
# 2    월별  02월       452      0.0   0.5   2.1  51.8    45.3   0.2       0.5
# 3    월별  03월       470      0.0   1.6   6.0  53.7    38.1   0.5       1.6
# 4    월별  04월       524      0.2   0.0   4.4  53.2    41.9   0.2       0.2
#
#    관광정보 보통  관광정보 만족  해당없음.1  관광정보 5점평균  관광정보 100점평균
# 0     12.4     86.0     0.5       4.17        79.32
# 1      4.0     95.2     0.5       4.35        83.76
# 2      2.1     97.1     0.2       4.42        85.57
# 3      6.0     91.8     0.5       4.29        82.26
# 4      4.4     95.1     0.2       4.37        84.24

# %%
tourinfo_2019 = tourinfo_2019.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족', '해당없음', '해당없음.1'], axis = 1)
tourinfo_2019.head(2)
# Out:
#      분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균
# 0  [전체]  NaN      6133       1.1     12.4     86.0       4.17        79.32
# 1    월별  01월       463       0.2      4.0     95.2       4.35        83.76

# %%
tourinfo_2019 = tourinfo_2019.iloc[1:13, :].reset_index(drop=True)
tourinfo_2019
# Out:
#     분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균
# 0   월별  01월       463       0.2      4.0     95.2       4.35        83.76
# 1   월별  02월       452       0.5      2.1     97.1       4.42        85.57
# 2   월별  03월       470       1.6      6.0     91.8       4.29        82.26
# 3   월별  04월       524       0.2      4.4     95.1       4.37        84.24
# 4   월별  05월       532       0.4      3.3     96.3       4.34        83.44
# 5   월별  06월       523       0.2      4.1     95.7       4.33        83.34
# 6   월별  07월       524       0.2      6.2     93.3       4.28        81.98
# 7   월별  08월       562       1.1     25.5     72.5       3.95        73.67
# 8   월별  09월       467       1.8     22.0     74.0       3.96        73.90
# 9   월별  10월       567       2.0     22.1     74.9       3.99        74.80
# 10  월별  11월       533       3.3     25.0     71.4       3.87        71.78
# 11  월별  12월       516       1.5     20.0     78.2       3.99        74.82

# %% [markdown]
# ## 관광지매력도 만족도

# %%
placecharm_2019 = pd.read_excel(DATA_PATH + 'plus/2019_관광지매력도.xlsx',
                            skiprows=1,
                            skipfooter=1)
placecharm_2019.head()
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족  ③보통   ④만족  ⑤매우 만족  해당없음  ①+②  \
# 0       [전체]        NaN  6133      0.1   0.3  7.0  38.7    53.7   0.3  0.3
# 1         월별        01월   463      0.5   0.0  1.9  35.2    62.1   0.2  0.5
# 2         월별        02월   452      0.0   0.0  1.8  29.0    69.3   0.0  0.0
# 3         월별        03월   470      0.0   0.2  2.8  40.0    57.0   0.0  0.2
# 4         월별        04월   524      0.0   0.0  1.5  44.0    54.4   0.0  0.0
#
#      ③   ④+⑤  해당없음.1  [5점 평균]  [100점 평균]
# 0  7.0  92.4     0.3     4.46      86.51
# 1  1.9  97.4     0.2     4.59      89.75
# 2  1.8  98.2     0.0     4.67      91.87
# 3  2.8  97.0     0.0     4.54      88.43
# 4  1.5  98.4     0.0     4.53      88.19

# %%
placecharm_2019 = placecharm_2019.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족', '해당없음', '해당없음.1'], axis = 1)
placecharm_2019.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①+②    ③   ④+⑤  [5점 평균]  [100점 평균]
# 0       [전체]        NaN  6133  0.3  7.0  92.4     4.46      86.51
# 1         월별        01월   463  0.5  1.9  97.4     4.59      89.75

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '관광지매력 사례수',
           '①+②' : '관광지매력 불만족',
           '③' : '관광지매력 보통',
           '④+⑤' : '관광지매력 만족',
           '[5점 평균]' : '관광지매력 5점평균',
            '[100점 평균]' : '관광지매력 100점평균'
           }
placecharm_2019 = placecharm_2019.rename(columns = columns)
placecharm_2019.head()
# Out:
#      분류 세부분류  관광지매력 사례수  관광지매력 불만족  관광지매력 보통  관광지매력 만족  관광지매력 5점평균  \
# 0  [전체]  NaN       6133        0.3       7.0      92.4        4.46
# 1    월별  01월        463        0.5       1.9      97.4        4.59
# 2    월별  02월        452        0.0       1.8      98.2        4.67
# 3    월별  03월        470        0.2       2.8      97.0        4.54
# 4    월별  04월        524        0.0       1.5      98.4        4.53
#
#    관광지매력 100점평균
# 0         86.51
# 1         89.75
# 2         91.87
# 3         88.43
# 4         88.19

# %%
placecharm_2019 = placecharm_2019.iloc[1:13, :].reset_index(drop=True)
placecharm_2019
# Out:
#     분류 세부분류  관광지매력 사례수  관광지매력 불만족  관광지매력 보통  관광지매력 만족  관광지매력 5점평균  \
# 0   월별  01월        463        0.5       1.9      97.4        4.59
# 1   월별  02월        452        0.0       1.8      98.2        4.67
# 2   월별  03월        470        0.2       2.8      97.0        4.54
# 3   월별  04월        524        0.0       1.5      98.4        4.53
# 4   월별  05월        532        0.0       1.6      98.2        4.66
# 5   월별  06월        523        0.2       1.9      97.9        4.63
# 6   월별  07월        524        0.0       1.6      98.4        4.67
# 7   월별  08월        562        0.7      14.3      84.8        4.24
# 8   월별  09월        467        0.7      14.3      84.7        4.27
# 9   월별  10월        567        0.5      10.9      88.1        4.26
# 10  월별  11월        533        1.2      18.2      80.1        4.22
# 11  월별  12월        516        0.0      11.3      87.6        4.32
#
#     관광지매력 100점평균
# 0          89.75
# 1          91.87
# 2          88.43
# 3          88.19
# ...

# %% [markdown]
# ## 교통정보 서비스
# - 2018/2019의 경우 교통 표지판 서비스로 되어있었으나 이후 교통정보 서비스 항목으로 바뀌어 통합하혀 전처리할 계획

# %%
trafficinfo_2019 = pd.read_excel(DATA_PATH + 'plus/2019_교통정보서비스.xlsx',
                            skiprows=1,
                            skipfooter=1)
trafficinfo_2019.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족  해당없음  ①+②  \
# 0       [전체]        NaN  6133      0.3   1.9  18.2  52.2    24.2   3.1  2.2
# 1         월별        01월   463      0.0   2.1   7.1  54.6    35.7   0.5  2.1
#
#       ③   ④+⑤  해당없음.1  [5점 평균]  [100점 평균]
# 0  18.2  76.4     3.1     4.01      75.31
# 1   7.1  90.3     0.5     4.25      81.13

# %%
trafficinfo_2019 = trafficinfo_2019.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족', '해당없음', '해당없음.1'], axis = 1)
trafficinfo_2019.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①+②     ③   ④+⑤  [5점 평균]  [100점 평균]
# 0       [전체]        NaN  6133  2.2  18.2  76.4     4.01      75.31
# 1         월별        01월   463  2.1   7.1  90.3     4.25      81.13

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '교통정보 사례수',
           '①+②' : '교통정보 불만족',
           '③' : '교통정보 보통',
           '④+⑤' : '교통정보 만족',
           '[5점 평균]' : '교통정보 5점평균',
            '[100점 평균]' : '교통정보 100점평균'
           }
trafficinfo_2019 = trafficinfo_2019.rename(columns = columns)
trafficinfo_2019.head()
# Out:
#      분류 세부분류  교통정보 사례수  교통정보 불만족  교통정보 보통  교통정보 만족  교통정보 5점평균  교통정보 100점평균
# 0  [전체]  NaN      6133       2.2     18.2     76.4       4.01        75.31
# 1    월별  01월       463       2.1      7.1     90.3       4.25        81.13
# 2    월별  02월       452       0.7      3.1     96.1       4.29        82.29
# 3    월별  03월       470       0.5      9.5     87.4       4.28        82.00
# 4    월별  04월       524       0.0      8.2     91.3       4.34        83.62

# %%
trafficinfo_2019 = trafficinfo_2019.iloc[1:13, :].reset_index(drop=True)
trafficinfo_2019
# Out:
#     분류 세부분류  교통정보 사례수  교통정보 불만족  교통정보 보통  교통정보 만족  교통정보 5점평균  교통정보 100점평균
# 0   월별  01월       463       2.1      7.1     90.3       4.25        81.13
# 1   월별  02월       452       0.7      3.1     96.1       4.29        82.29
# 2   월별  03월       470       0.5      9.5     87.4       4.28        82.00
# 3   월별  04월       524       0.0      8.2     91.3       4.34        83.62
# 4   월별  05월       532       0.4     10.0     84.3       4.16        78.90
# 5   월별  06월       523       0.5     19.1     78.6       3.99        74.79
# 6   월별  07월       524       1.4     18.1     77.8       3.96        74.03
# 7   월별  08월       562       3.6     26.7     67.9       3.82        70.55
# 8   월별  09월       467       2.8     32.7     58.6       3.73        68.24
# 9   월별  10월       567       5.3     25.1     66.1       3.84        70.98
# 10  월별  11월       533       5.8     29.9     60.2       3.71        67.71
# 11  월별  12월       516       3.1     25.3     63.9       3.83        70.84

# %% [markdown]
# ## 방문관광지 편의성 만족도

# %%
conv_2019 = pd.read_excel(DATA_PATH + 'plus/2019_방문관광지편의성.xlsx',
                            skiprows=1,
                            skipfooter=1)
conv_2019.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족  ③보통   ④만족  ⑤매우 만족  해당없음  ①+②  \
# 0       [전체]        NaN  6133      0.0   0.5  9.9  50.0    39.4   0.2  0.5
# 1         월별        01월   463      0.2   0.0  3.3  50.5    45.9   0.0  0.2
#
#      ③   ④+⑤  해당없음.1  [5점 평균]  [100점 평균]
# 0  9.9  89.4     0.2     4.28      82.12
# 1  3.3  96.4     0.0     4.42      85.47

# %%
conv_2019 = conv_2019.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족', '해당없음', '해당없음.1'], axis = 1)
conv_2019.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①+②    ③   ④+⑤  [5점 평균]  [100점 평균]
# 0       [전체]        NaN  6133  0.5  9.9  89.4     4.28      82.12
# 1         월별        01월   463  0.2  3.3  96.4     4.42      85.47

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '관광지편의성 사례수',
           '①+②' : '관광지편의성 불만족',
           '③' : '관광지편의성 보통',
           '④+⑤' : '관광지편의성 만족',
           '[5점 평균]' : '관광지편의성 5점평균',
            '[100점 평균]' : '관광지편의성 100점평균'
           }
conv_2019 = conv_2019.rename(columns = columns)
conv_2019.head()
# Out:
#      분류 세부분류  관광지편의성 사례수  관광지편의성 불만족  관광지편의성 보통  관광지편의성 만족  관광지편의성 5점평균  \
# 0  [전체]  NaN        6133         0.5        9.9       89.4         4.28
# 1    월별  01월         463         0.2        3.3       96.4         4.42
# 2    월별  02월         452         0.0        0.8       98.9         4.52
# 3    월별  03월         470         0.2        4.2       95.6         4.44
# 4    월별  04월         524         0.2        3.0       96.7         4.45
#
#    관광지편의성 100점평균
# 0          82.12
# 1          85.47
# 2          87.93
# 3          85.97
# 4          86.13

# %%
conv_2019 = conv_2019.iloc[1:13, :].reset_index(drop=True)
conv_2019
# Out:
#     분류 세부분류  관광지편의성 사례수  관광지편의성 불만족  관광지편의성 보통  관광지편의성 만족  관광지편의성 5점평균  \
# 0   월별  01월         463         0.2        3.3       96.4         4.42
# 1   월별  02월         452         0.0        0.8       98.9         4.52
# 2   월별  03월         470         0.2        4.2       95.6         4.44
# 3   월별  04월         524         0.2        3.0       96.7         4.45
# 4   월별  05월         532         0.0        2.6       97.4         4.43
# 5   월별  06월         523         0.0        3.3       96.7         4.41
# 6   월별  07월         524         0.0        3.2       96.7         4.36
# 7   월별  08월         562         0.9       18.3       80.6         4.10
# 8   월별  09월         467         0.9       20.4       77.7         4.04
# 9   월별  10월         567         0.5       16.7       82.6         4.15
# 10  월별  11월         533         2.4       25.6       71.6         3.97
# 11  월별  12월         516         0.8       14.6       84.5         4.21
#
#     관광지편의성 100점평균
# 0           85.47
# ...

# %% [markdown]
# ## 쇼핑 만족도

# %%
shopping_2019 = pd.read_excel(DATA_PATH + 'plus/2019_쇼핑.xlsx',
                            skiprows=1,
                            skipfooter=1)
shopping_2019.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족  해당없음  ①+②  \
# 0       [전체]        NaN  6133      0.3   1.7  16.3  45.9    23.3  12.5  2.1
# 1         월별        01월   463      0.0   0.5   5.3  50.6    31.1  12.5  0.5
#
#       ③   ④+⑤  해당없음.1  [5점 평균]  [100점 평균]
# 0  16.3  69.2    12.5     4.03      75.75
# 1   5.3  81.7    12.5     4.28      82.10

# %%
shopping_2019 = shopping_2019.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족', '해당없음', '해당없음.1'], axis = 1)
shopping_2019.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①+②     ③   ④+⑤  [5점 평균]  [100점 평균]
# 0       [전체]        NaN  6133  2.1  16.3  69.2     4.03      75.75
# 1         월별        01월   463  0.5   5.3  81.7     4.28      82.10

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '쇼핑 사례수',
           '①+②' : '쇼핑 불만족',
           '③' : '쇼핑 보통',
           '④+⑤' : '쇼핑 만족',
           '[5점 평균]' : '쇼핑 5점평균',
            '[100점 평균]' : '쇼핑 100점평균'
           }
shopping_2019 = shopping_2019.rename(columns = columns)
shopping_2019.head()
# Out:
#      분류 세부분류  쇼핑 사례수  쇼핑 불만족  쇼핑 보통  쇼핑 만족  쇼핑 5점평균  쇼핑 100점평균
# 0  [전체]  NaN    6133     2.1   16.3   69.2     4.03      75.75
# 1    월별  01월     463     0.5    5.3   81.7     4.28      82.10
# 2    월별  02월     452     0.0    2.7   86.4     4.42      85.42
# 3    월별  03월     470     0.5    8.3   73.8     4.19      79.66
# 4    월별  04월     524     0.3    5.8   80.7     4.28      82.06

# %%
shopping_2019 = shopping_2019 .iloc[1:13, :].reset_index(drop=True)
shopping_2019
# Out:
#     분류 세부분류  쇼핑 사례수  쇼핑 불만족  쇼핑 보통  쇼핑 만족  쇼핑 5점평균  쇼핑 100점평균
# 0   월별  01월     463     0.5    5.3   81.7     4.28      82.10
# 1   월별  02월     452     0.0    2.7   86.4     4.42      85.42
# 2   월별  03월     470     0.5    8.3   73.8     4.19      79.66
# 3   월별  04월     524     0.3    5.8   80.7     4.28      82.06
# 4   월별  05월     532     0.9    9.5   79.3     4.16      79.01
# 5   월별  06월     523     1.2   12.1   73.4     4.10      77.58
# 6   월별  07월     524     1.2   15.3   67.4     4.00      75.04
# 7   월별  08월     562     3.8   31.0   53.1     3.70      67.45
# 8   월별  09월     467     2.3   24.4   60.2     3.89      72.29
# 9   월별  10월     567     5.0   23.2   59.9     3.86      71.55
# 10  월별  11월     533     5.1   27.9   57.1     3.73      68.20
# 11  월별  12월     516     3.0   25.3   62.5     3.88      72.09

# %% [markdown]
# ## 숙박시설 만족도

# %%
accom_2019 = pd.read_excel(DATA_PATH + 'plus/2019_숙박시설.xlsx',
                            skiprows=1,
                            skipfooter=1)
accom_2019.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족  ③보통   ④만족  ⑤매우 만족  해당없음  ①+②  \
# 0       [전체]        NaN  6133      0.1   0.6  6.4  44.8    45.5   2.6  0.7
# 1         월별        01월   463      0.2   0.0  2.2  40.1    54.6   2.9  0.2
#
#      ③   ④+⑤  해당없음.1  [5점 평균]  [100점 평균]
# 0  6.4  90.3     2.6     4.39      84.63
# 1  2.2  94.7     2.9     4.53      88.31

# %%
accom_2019 = accom_2019.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족', '해당없음', '해당없음.1'], axis = 1)
accom_2019.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①+②    ③   ④+⑤  [5점 평균]  [100점 평균]
# 0       [전체]        NaN  6133  0.7  6.4  90.3     4.39      84.63
# 1         월별        01월   463  0.2  2.2  94.7     4.53      88.31

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '숙박 사례수',
           '①+②' : '숙박 불만족',
           '③' : '숙박 보통',
           '④+⑤' : '숙박 만족',
           '[5점 평균]' : '숙박 5점평균',
            '[100점 평균]' : '숙박 100점평균'
           }
accom_2019 = accom_2019.rename(columns = columns)
accom_2019.head(2)
# Out:
#      분류 세부분류  숙박 사례수  숙박 불만족  숙박 보통  숙박 만족  숙박 5점평균  숙박 100점평균
# 0  [전체]  NaN    6133     0.7    6.4   90.3     4.39      84.63
# 1    월별  01월     463     0.2    2.2   94.7     4.53      88.31

# %%
accom_2019 = accom_2019.iloc[1:13, :].reset_index(drop=True)
accom_2019
# Out:
#     분류 세부분류  숙박 사례수  숙박 불만족  숙박 보통  숙박 만족  숙박 5점평균  숙박 100점평균
# 0   월별  01월     463     0.2    2.2   94.7     4.53      88.31
# 1   월별  02월     452     0.3    1.0   97.3     4.51      87.71
# 2   월별  03월     470     0.0    2.9   95.0     4.54      88.43
# 3   월별  04월     524     0.3    0.9   98.0     4.64      90.93
# 4   월별  05월     532     0.0    3.1   95.1     4.46      86.43
# 5   월별  06월     523     0.7    1.7   95.6     4.44      86.05
# 6   월별  07월     524     0.0    3.6   95.5     4.45      86.18
# 7   월별  08월     562     2.2   12.4   82.0     4.25      81.23
# 8   월별  09월     467     0.7   12.2   82.5     4.19      79.64
# 9   월별  10월     567     1.4   12.0   85.1     4.25      81.30
# 10  월별  11월     533     2.1   12.6   80.4     4.15      78.84
# 11  월별  12월     516     0.2   10.6   85.0     4.25      81.22

# %% [markdown]
# ## 여행경비 만족도

# %%
budget_2019 = pd.read_excel(DATA_PATH + 'plus/2019_여행경비.xlsx',
                            skiprows=1,
                            skipfooter=1)
budget_2019.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족  해당없음   ①+②  \
# 0       [전체]        NaN  6133      3.4  10.2  30.4  44.1    11.8   0.1  13.6
# 1         월별        01월   463      0.5   3.2  23.2  52.3    20.9   0.0   3.6
#
#       ③   ④+⑤  해당없음.1  [5점 평균]  [100점 평균]
# 0  30.4  55.9     0.1     3.51      62.67
# 1  23.2  73.2     0.0     3.90      72.48

# %%
budget_2019 = budget_2019.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족', '해당없음', '해당없음.1'], axis = 1)
budget_2019.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수   ①+②     ③   ④+⑤  [5점 평균]  [100점 평균]
# 0       [전체]        NaN  6133  13.6  30.4  55.9     3.51      62.67
# 1         월별        01월   463   3.6  23.2  73.2     3.90      72.48

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '여행경비 사례수',
           '①+②' : '여행경비 불만족',
           '③' : '여행경비 보통',
           '④+⑤' : '여행경비 만족',
           '[5점 평균]' : '여행경비 5점평균',
            '[100점 평균]' : '여행경비 100점평균'
           }
budget_2019 = budget_2019.rename(columns = columns)
budget_2019.head(2)
# Out:
#      분류 세부분류  여행경비 사례수  여행경비 불만족  여행경비 보통  여행경비 만족  여행경비 5점평균  여행경비 100점평균
# 0  [전체]  NaN      6133      13.6     30.4     55.9       3.51        62.67
# 1    월별  01월       463       3.6     23.2     73.2       3.90        72.48

# %%
budget_2019 = budget_2019.iloc[1:13, :].reset_index(drop=True)
budget_2019
# Out:
#     분류 세부분류  여행경비 사례수  여행경비 불만족  여행경비 보통  여행경비 만족  여행경비 5점평균  여행경비 100점평균
# 0   월별  01월       463       3.6     23.2     73.2       3.90        72.48
# 1   월별  02월       452       5.1     16.9     77.8       3.94        73.54
# 2   월별  03월       470       5.0     24.5     70.4       3.80        69.97
# 3   월별  04월       524       4.3     28.2     67.6       3.77        69.21
# 4   월별  05월       532       8.6     28.7     62.7       3.65        66.16
# 5   월별  06월       523       6.3     29.3     64.4       3.66        66.43
# 6   월별  07월       524       5.7     30.8     63.5       3.66        66.55
# 7   월별  08월       562      31.6     32.8     35.6       3.01        50.34
# 8   월별  09월       467      20.7     32.6     45.7       3.29        57.21
# 9   월별  10월       567      22.7     36.7     40.7       3.21        55.21
# 10  월별  11월       533      24.1     37.4     38.0       3.15        53.76
# 11  월별  12월       516      21.1     39.7     39.1       3.22        55.45

# %% [markdown]
# ## 음식 만족도

# %%
food_2019 = pd.read_excel(DATA_PATH + 'plus/2019_음식.xlsx',
                            skiprows=1,
                            skipfooter=1)
food_2019.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족  ③보통   ④만족  ⑤매우 만족  해당없음  ①+②  \
# 0       [전체]        NaN  6133      0.4   1.4  9.7  50.3    35.3   3.0  1.7
# 1         월별        01월   463      0.2   0.0  4.3  50.1    45.2   0.1  0.2
#
#      ③   ④+⑤  해당없음.1  [5점 평균]  [100점 평균]
# 0  9.7  85.6     3.0     4.22      80.58
# 1  4.3  95.3     0.1     4.40      85.06

# %%
food_2019 = food_2019.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족', '해당없음', '해당없음.1'], axis = 1)
food_2019.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①+②    ③   ④+⑤  [5점 평균]  [100점 평균]
# 0       [전체]        NaN  6133  1.7  9.7  85.6     4.22      80.58
# 1         월별        01월   463  0.2  4.3  95.3     4.40      85.06

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '음식 사례수',
           '①+②' : '음식 불만족',
           '③' : '음식 보통',
           '④+⑤' : '음식 만족',
           '[5점 평균]' : '음식 5점평균',
            '[100점 평균]' : '음식 100점평균'
           }
food_2019 = food_2019.rename(columns = columns)
food_2019.head(2)
# Out:
#      분류 세부분류  음식 사례수  음식 불만족  음식 보통  음식 만족  음식 5점평균  음식 100점평균
# 0  [전체]  NaN    6133     1.7    9.7   85.6     4.22      80.58
# 1    월별  01월     463     0.2    4.3   95.3     4.40      85.06

# %%
food_2019 = food_2019.iloc[1:13, :].reset_index(drop=True)
food_2019
# Out:
#     분류 세부분류  음식 사례수  음식 불만족  음식 보통  음식 만족  음식 5점평균  음식 100점평균
# 0   월별  01월     463     0.2    4.3   95.3     4.40      85.06
# 1   월별  02월     452     0.0    3.1   95.3     4.40      85.09
# 2   월별  03월     470     0.8    5.5   92.1     4.30      82.39
# 3   월별  04월     524     0.7    3.2   93.1     4.35      83.80
# 4   월별  05월     532     0.2    7.0   91.2     4.32      83.10
# 5   월별  06월     523     1.0    3.7   93.8     4.33      83.27
# 6   월별  07월     524     0.5    3.1   94.1     4.38      84.44
# 7   월별  08월     562     4.7   18.9   74.7     3.96      74.04
# 8   월별  09월     467     4.2   16.2   73.1     4.07      76.87
# 9   월별  10월     567     2.7   16.6   74.6     4.07      76.68
# 10  월별  11월     533     3.8   19.2   71.7     3.98      74.38
# 11  월별  12월     516     1.6   13.5   81.3     4.16      79.05

# %% [markdown]
# ## 제주도 내 대중교통 만족도

# %%
pt_2019 = pd.read_excel(DATA_PATH + 'plus/2019_제주도내대중교통.xlsx',
                            skiprows=1,
                            skipfooter=1)
pt_2019.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족  ③보통  ④만족  ⑤매우 만족  해당없음  ①+②  \
# 0       [전체]        NaN  6133      0.3   1.3  3.4  2.0     0.7  92.3  1.6
# 1         월별        01월   463      0.7   1.2  5.4  2.2     0.8  89.7  2.0
#
#      ③  ④+⑤  해당없음.1  [5점 평균]  [100점 평균]
# 0  3.4  2.6    92.3     3.18      54.46
# 1  5.4  2.9    89.7     3.10      52.43

# %%
pt_2019 = pt_2019.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족', '해당없음', '해당없음.1'], axis = 1)
pt_2019.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①+②    ③  ④+⑤  [5점 평균]  [100점 평균]
# 0       [전체]        NaN  6133  1.6  3.4  2.6     3.18      54.46
# 1         월별        01월   463  2.0  5.4  2.9     3.10      52.43

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '대중교통 사례수',
           '①+②' : '대중교통 불만족',
           '③' : '대중교통 보통',
           '④+⑤' : '대중교통 만족',
           '[5점 평균]' : '대중교통 5점평균',
            '[100점 평균]' : '대중교통 100점평균'
           }
pt_2019 = pt_2019.rename(columns = columns)
pt_2019.head(2)
# Out:
#      분류 세부분류  대중교통 사례수  대중교통 불만족  대중교통 보통  대중교통 만족  대중교통 5점평균  대중교통 100점평균
# 0  [전체]  NaN      6133       1.6      3.4      2.6       3.18        54.46
# 1    월별  01월       463       2.0      5.4      2.9       3.10        52.43

# %%
pt_2019 = pt_2019.iloc[1:13, :].reset_index(drop=True)
pt_2019
# Out:
#     분류 세부분류  대중교통 사례수  대중교통 불만족  대중교통 보통  대중교통 만족  대중교통 5점평균  대중교통 100점평균
# 0   월별  01월       463       2.0      5.4      2.9       3.10        52.43
# 1   월별  02월       452       0.5      1.5      2.6       3.64        65.91
# 2   월별  03월       470       0.9      4.5      2.5       3.24        55.93
# 3   월별  04월       524       0.0      0.9      0.9       3.49        62.16
# 4   월별  05월       532       0.6      1.1      1.1       3.26        56.48
# 5   월별  06월       523       1.1      2.1      2.3       3.25        56.18
# 6   월별  07월       524       1.1      3.7      2.0       3.20        54.97
# 7   월별  08월       562       1.3      3.8      3.4       3.30        57.55
# 8   월별  09월       467       3.2      5.6      5.0       3.23        55.81
# 9   월별  10월       567       1.6      2.6      2.5       3.14        53.38
# 10  월별  11월       533       3.1      5.0      3.8       3.06        51.58
# 11  월별  12월       516       3.9      5.0      2.8       2.93        48.18

# %% [markdown]
# ## 지역주민 친절 만족도

# %%
kind_2019 = pd.read_excel(DATA_PATH + 'plus/2019_지역주민친절.xlsx',
                            skiprows=1,
                            skipfooter=1)
kind_2019.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족  해당없음  ①+②  \
# 0       [전체]        NaN  6133      0.6   2.0  20.7  54.3    19.1   3.4  2.5
# 1         월별        01월   463      0.0   1.7  14.5  56.0    23.9   4.0  1.7
#
#       ③   ④+⑤  해당없음.1  [5점 평균]  [100점 평균]
# 0  20.7  73.4     3.4     3.93      73.14
# 1  14.5  79.8     4.0     4.06      76.55

# %%
kind_2019 = kind_2019.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족', '해당없음', '해당없음.1'], axis = 1)
kind_2019.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①+②     ③   ④+⑤  [5점 평균]  [100점 평균]
# 0       [전체]        NaN  6133  2.5  20.7  73.4     3.93      73.14
# 1         월별        01월   463  1.7  14.5  79.8     4.06      76.55

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '주민친절 사례수',
           '①+②' : '주민친절 불만족',
           '③' : '주민친절 보통',
           '④+⑤' : '주민친절 만족',
           '[5점 평균]' : '주민친절 5점평균',
            '[100점 평균]' : '주민친절 100점평균'
           }
kind_2019 = kind_2019.rename(columns = columns)
kind_2019.head(2)
# Out:
#      분류 세부분류  주민친절 사례수  주민친절 불만족  주민친절 보통  주민친절 만족  주민친절 5점평균  주민친절 100점평균
# 0  [전체]  NaN      6133       2.5     20.7     73.4       3.93        73.14
# 1    월별  01월       463       1.7     14.5     79.8       4.06        76.55

# %%
kind_2019 = kind_2019.iloc[1:13, :].reset_index(drop=True)
kind_2019
# Out:
#     분류 세부분류  주민친절 사례수  주민친절 불만족  주민친절 보통  주민친절 만족  주민친절 5점평균  주민친절 100점평균
# 0   월별  01월       463       1.7     14.5     79.8       4.06        76.55
# 1   월별  02월       452       0.7     12.7     82.0       4.12        77.96
# 2   월별  03월       470       0.7     14.3     80.7       4.07        76.86
# 3   월별  04월       524       0.8     16.9     77.2       3.98        74.61
# 4   월별  05월       532       1.1     16.1     81.3       3.99        74.71
# 5   월별  06월       523       1.2     13.7     79.0       4.01        75.37
# 6   월별  07월       524       0.7     16.2     75.3       4.02        75.61
# 7   월별  08월       562       5.9     29.5     63.3       3.76        68.92
# 8   월별  09월       467       2.8     25.6     69.0       3.85        71.36
# 9   월별  10월       567       4.7     26.0     67.5       3.82        70.55
# 10  월별  11월       533       5.3     27.9     65.4       3.78        69.50
# 11  월별  12월       516       4.0     31.5     64.0       3.72        68.01

# %% [markdown]
# ## 치안 만족도

# %%
safety_2019 = pd.read_excel(DATA_PATH + 'plus/2019_치안.xlsx',
                            skiprows=1,
                            skipfooter=1)
safety_2019.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족  ③보통   ④만족  ⑤매우 만족  해당없음  ①+②  \
# 0       [전체]        NaN  6133      0.1   0.8  8.2  69.0    21.5   0.3  1.0
# 1         월별        01월   463      0.0   0.0  2.7  68.2    28.1   1.0  0.0
#
#      ③   ④+⑤  해당없음.1  [5점 평균]  [100점 평균]
# 0  8.2  90.5     0.3     4.11      77.83
# 1  2.7  96.3     1.0     4.26      81.41

# %%
safety_2019 = safety_2019.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족', '해당없음', '해당없음.1'], axis = 1)
safety_2019.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①+②    ③   ④+⑤  [5점 평균]  [100점 평균]
# 0       [전체]        NaN  6133  1.0  8.2  90.5     4.11      77.83
# 1         월별        01월   463  0.0  2.7  96.3     4.26      81.41

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '치안 사례수',
           '①+②' : '치안 불만족',
           '③' : '치안 보통',
           '④+⑤' : '치안 만족',
           '[5점 평균]' : '치안 5점평균',
            '[100점 평균]' : '치안 100점평균'
           }
safety_2019 = safety_2019.rename(columns = columns)
safety_2019.head(2)
# Out:
#      분류 세부분류  치안 사례수  치안 불만족  치안 보통  치안 만족  치안 5점평균  치안 100점평균
# 0  [전체]  NaN    6133     1.0    8.2   90.5     4.11      77.83
# 1    월별  01월     463     0.0    2.7   96.3     4.26      81.41

# %%
safety_2019 = safety_2019.iloc[1:13, :].reset_index(drop=True)
safety_2019
# Out:
#     분류 세부분류  치안 사례수  치안 불만족  치안 보통  치안 만족  치안 5점평균  치안 100점평균
# 0   월별  01월     463     0.0    2.7   96.3     4.26      81.41
# 1   월별  02월     452     0.5    1.0   98.2     4.31      82.64
# 2   월별  03월     470     0.5    4.1   95.2     4.20      80.02
# 3   월별  04월     524     0.2    2.5   97.1     4.17      79.37
# 4   월별  05월     532     0.0    2.4   97.6     4.19      79.84
# 5   월별  06월     523     0.0    2.8   97.2     4.13      78.22
# 6   월별  07월     524     0.2    1.2   98.6     4.14      78.61
# 7   월별  08월     562     3.1   16.4   80.0     3.98      74.38
# 8   월별  09월     467     0.9   15.9   82.0     4.05      76.16
# 9   월별  10월     567     0.9   16.5   82.1     4.01      75.36
# 10  월별  11월     533     2.8   15.4   81.3     4.01      75.22
# 11  월별  12월     516     2.0   14.7   83.3     3.97      74.22

# %% [markdown]
# ## 통합

# %%
re = pd.merge(tourinfo_2019, placecharm_2019, on=['분류', '세부분류'])

# %%
re1 = pd.merge(re, trafficinfo_2019, on=['분류', '세부분류'])
re1.head(2)
# Out:
#    분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균  \
# 0  월별  01월       463       0.2      4.0     95.2       4.35        83.76
# 1  월별  02월       452       0.5      2.1     97.1       4.42        85.57
#
#    관광지매력 사례수  관광지매력 불만족  관광지매력 보통  관광지매력 만족  관광지매력 5점평균  관광지매력 100점평균  \
# 0        463        0.5       1.9      97.4        4.59         89.75
# 1        452        0.0       1.8      98.2        4.67         91.87
#
#    교통정보 사례수  교통정보 불만족  교통정보 보통  교통정보 만족  교통정보 5점평균  교통정보 100점평균
# 0       463       2.1      7.1     90.3       4.25        81.13
# 1       452       0.7      3.1     96.1       4.29        82.29

# %%
re2 = pd.merge(re1, conv_2019, on=['분류', '세부분류'])
re2.head(2)
# Out:
#    분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균  \
# 0  월별  01월       463       0.2      4.0     95.2       4.35        83.76
# 1  월별  02월       452       0.5      2.1     97.1       4.42        85.57
#
#    관광지매력 사례수  관광지매력 불만족  ...  교통정보 보통  교통정보 만족  교통정보 5점평균  교통정보 100점평균  \
# 0        463        0.5  ...      7.1     90.3       4.25        81.13
# 1        452        0.0  ...      3.1     96.1       4.29        82.29
#
#    관광지편의성 사례수  관광지편의성 불만족  관광지편의성 보통  관광지편의성 만족  관광지편의성 5점평균  관광지편의성 100점평균
# 0         463         0.2        3.3       96.4         4.42          85.47
# 1         452         0.0        0.8       98.9         4.52          87.93
#
# [2 rows x 26 columns]

# %%
re3 = pd.merge(re2, shopping_2019, on=['분류', '세부분류'])
re3
# Out:
#     분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균  \
# 0   월별  01월       463       0.2      4.0     95.2       4.35        83.76
# 1   월별  02월       452       0.5      2.1     97.1       4.42        85.57
# 2   월별  03월       470       1.6      6.0     91.8       4.29        82.26
# 3   월별  04월       524       0.2      4.4     95.1       4.37        84.24
# 4   월별  05월       532       0.4      3.3     96.3       4.34        83.44
# 5   월별  06월       523       0.2      4.1     95.7       4.33        83.34
# 6   월별  07월       524       0.2      6.2     93.3       4.28        81.98
# 7   월별  08월       562       1.1     25.5     72.5       3.95        73.67
# 8   월별  09월       467       1.8     22.0     74.0       3.96        73.90
# 9   월별  10월       567       2.0     22.1     74.9       3.99        74.80
# 10  월별  11월       533       3.3     25.0     71.4       3.87        71.78
# 11  월별  12월       516       1.5     20.0     78.2       3.99        74.82
#
# ...

# %%
re4 = pd.merge(re3, accom_2019, on=['분류', '세부분류'])
re4.head(2)
# Out:
#    분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균  \
# 0  월별  01월       463       0.2      4.0     95.2       4.35        83.76
# 1  월별  02월       452       0.5      2.1     97.1       4.42        85.57
#
#    관광지매력 사례수  관광지매력 불만족  ...  쇼핑 보통  쇼핑 만족  쇼핑 5점평균  쇼핑 100점평균  숙박 사례수  \
# 0        463        0.5  ...    5.3   81.7     4.28      82.10     463
# 1        452        0.0  ...    2.7   86.4     4.42      85.42     452
#
#    숙박 불만족  숙박 보통  숙박 만족  숙박 5점평균  숙박 100점평균
# 0     0.2    2.2   94.7     4.53      88.31
# 1     0.3    1.0   97.3     4.51      87.71
#
# [2 rows x 38 columns]

# %%
re5 = pd.merge(re4, budget_2019, on=['분류', '세부분류'])
re5.head(2)
# Out:
#    분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균  \
# 0  월별  01월       463       0.2      4.0     95.2       4.35        83.76
# 1  월별  02월       452       0.5      2.1     97.1       4.42        85.57
#
#    관광지매력 사례수  관광지매력 불만족  ...  숙박 보통  숙박 만족  숙박 5점평균  숙박 100점평균  여행경비 사례수  \
# 0        463        0.5  ...    2.2   94.7     4.53      88.31       463
# 1        452        0.0  ...    1.0   97.3     4.51      87.71       452
#
#    여행경비 불만족  여행경비 보통  여행경비 만족  여행경비 5점평균  여행경비 100점평균
# 0       3.6     23.2     73.2       3.90        72.48
# 1       5.1     16.9     77.8       3.94        73.54
#
# [2 rows x 44 columns]

# %%
re6 = pd.merge(re5, food_2019, on=['분류', '세부분류'])
re6.head(2)
# Out:
#    분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균  \
# 0  월별  01월       463       0.2      4.0     95.2       4.35        83.76
# 1  월별  02월       452       0.5      2.1     97.1       4.42        85.57
#
#    관광지매력 사례수  관광지매력 불만족  ...  여행경비 보통  여행경비 만족  여행경비 5점평균  여행경비 100점평균  \
# 0        463        0.5  ...     23.2     73.2       3.90        72.48
# 1        452        0.0  ...     16.9     77.8       3.94        73.54
#
#    음식 사례수  음식 불만족  음식 보통  음식 만족  음식 5점평균  음식 100점평균
# 0     463     0.2    4.3   95.3      4.4      85.06
# 1     452     0.0    3.1   95.3      4.4      85.09
#
# [2 rows x 50 columns]

# %%
re7 = pd.merge(re6, pt_2019, on=['분류', '세부분류'])
re7.head(2)
# Out:
#    분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균  \
# 0  월별  01월       463       0.2      4.0     95.2       4.35        83.76
# 1  월별  02월       452       0.5      2.1     97.1       4.42        85.57
#
#    관광지매력 사례수  관광지매력 불만족  ...  음식 보통  음식 만족  음식 5점평균  음식 100점평균  대중교통 사례수  \
# 0        463        0.5  ...    4.3   95.3      4.4      85.06       463
# 1        452        0.0  ...    3.1   95.3      4.4      85.09       452
#
#    대중교통 불만족  대중교통 보통  대중교통 만족  대중교통 5점평균  대중교통 100점평균
# 0       2.0      5.4      2.9       3.10        52.43
# 1       0.5      1.5      2.6       3.64        65.91
#
# [2 rows x 56 columns]

# %%
re8 = pd.merge(re7, kind_2019, on=['분류', '세부분류'])
re8.head(2)
# Out:
#    분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균  \
# 0  월별  01월       463       0.2      4.0     95.2       4.35        83.76
# 1  월별  02월       452       0.5      2.1     97.1       4.42        85.57
#
#    관광지매력 사례수  관광지매력 불만족  ...  대중교통 보통  대중교통 만족  대중교통 5점평균  대중교통 100점평균  \
# 0        463        0.5  ...      5.4      2.9       3.10        52.43
# 1        452        0.0  ...      1.5      2.6       3.64        65.91
#
#    주민친절 사례수  주민친절 불만족  주민친절 보통  주민친절 만족  주민친절 5점평균  주민친절 100점평균
# 0       463       1.7     14.5     79.8       4.06        76.55
# 1       452       0.7     12.7     82.0       4.12        77.96
#
# [2 rows x 62 columns]

# %%
result_2019 = pd.merge(re8, safety_2019, on=['분류', '세부분류'])
result_2019.head(2)
# Out:
#    분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균  \
# 0  월별  01월       463       0.2      4.0     95.2       4.35        83.76
# 1  월별  02월       452       0.5      2.1     97.1       4.42        85.57
#
#    관광지매력 사례수  관광지매력 불만족  ...  주민친절 보통  주민친절 만족  주민친절 5점평균  주민친절 100점평균  \
# 0        463        0.5  ...     14.5     79.8       4.06        76.55
# 1        452        0.0  ...     12.7     82.0       4.12        77.96
#
#    치안 사례수  치안 불만족  치안 보통  치안 만족  치안 5점평균  치안 100점평균
# 0     463     0.0    2.7   96.3     4.26      81.41
# 1     452     0.5    1.0   98.2     4.31      82.64
#
# [2 rows x 68 columns]

# %%
result_2019.to_csv("result_2019.csv", index = True)
