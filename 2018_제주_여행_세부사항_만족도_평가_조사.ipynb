# %% [markdown]
# # 2018 제주 여행 세부사항 만족도 평가 조사
# - 원래는 렌터카 등 교통이용 평가도 포함되어 있으나 DB문제로 인해 데이터를 얻을 수 없어서 뺌

# %% [markdown]
# ## 라이브러리

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 데이터 경로설정

# %%
DATA_PATH = '/content/drive/MyDrive/Colab Notebooks/jeju/'

# %% [markdown]
# ## 관광정보 만족도

# %%
tourinfo_2018 = pd.read_excel(DATA_PATH + 'plus/2018_관광정보서비스.xlsx',
                            skiprows=1,
                            skipfooter=1)
tourinfo_2018.head()
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족  ①+②     ③  \
# 0       [전체]        NaN  6007      0.3   1.0  10.6  55.3    32.7  1.3  10.6
# 1         월별        01월   429      1.7   5.6  38.6  37.3    16.7  7.4  38.6
# 2         월별        02월   367      1.2   3.6  40.6  41.7    12.9  4.8  40.6
# 3         월별        03월   462      0.5   0.9  22.5  52.1    23.9  1.4  22.5
# 4         월별        04월   574      0.0   0.5   5.5  53.1    40.9  0.5   5.5
#
#     ④+⑤  [5점 평균]  [100점 평균]
# 0  88.1     4.19      79.79
# 1  54.0     3.62      65.39
# 2  54.6     3.61      65.37
# 3  76.0     3.98      74.50
# 4  94.0     4.34      83.59

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '관광정보 사례수',
           '①+②' : '관광정보 불만족',
           '③' : '관광정보 보통',
           '④+⑤' : '관광정보 만족',
           '[5점 평균]' : '관광정보 5점평균',
            '[100점 평균]' : '관광정보 100점평균'
           }
tourinfo_2018 = tourinfo_2018.rename(columns = columns)
tourinfo_2018.head()
# Out:
#      분류 세부분류  관광정보 사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족  관광정보 불만족  관광정보 보통  \
# 0  [전체]  NaN      6007      0.3   1.0  10.6  55.3    32.7       1.3     10.6
# 1    월별  01월       429      1.7   5.6  38.6  37.3    16.7       7.4     38.6
# 2    월별  02월       367      1.2   3.6  40.6  41.7    12.9       4.8     40.6
# 3    월별  03월       462      0.5   0.9  22.5  52.1    23.9       1.4     22.5
# 4    월별  04월       574      0.0   0.5   5.5  53.1    40.9       0.5      5.5
#
#    관광정보 만족  관광정보 5점평균  관광정보 100점평균
# 0     88.1       4.19        79.79
# 1     54.0       3.62        65.39
# 2     54.6       3.61        65.37
# 3     76.0       3.98        74.50
# 4     94.0       4.34        83.59

# %%
tourinfo_2018 = tourinfo_2018.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족'], axis = 1)
tourinfo_2018
# Out:
#       분류          세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  \
# 0   [전체]           NaN      6007       1.3     10.6     88.1       4.19
# 1     월별           01월       429       7.4     38.6     54.0       3.62
# 2     월별           02월       367       4.8     40.6     54.6       3.61
# 3     월별           03월       462       1.4     22.5     76.0       3.98
# 4     월별           04월       574       0.5      5.5     94.0       4.34
# 5     월별           05월       563       0.2      1.4     98.4       4.35
# 6     월별           06월       554       0.9      4.8     94.2       4.29
# 7     월별           07월       523       0.8      5.7     93.6       4.25
# 8     월별           08월       529       0.8      7.0     92.2       4.23
# 9     월별           09월       510       0.7      2.8     96.5       4.45
# 10    월별           10월       529       0.0      4.4     95.6       4.33
# 11    월별           11월       487       0.5      3.7     95.8       4.32
# ...

# %%
tourinfo_2018 = tourinfo_2018.iloc[1:13, :].reset_index(drop=True)
tourinfo_2018
# Out:
#     분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균
# 0   월별  01월       429       7.4     38.6     54.0       3.62        65.39
# 1   월별  02월       367       4.8     40.6     54.6       3.61        65.37
# 2   월별  03월       462       1.4     22.5     76.0       3.98        74.50
# 3   월별  04월       574       0.5      5.5     94.0       4.34        83.59
# 4   월별  05월       563       0.2      1.4     98.4       4.35        83.78
# 5   월별  06월       554       0.9      4.8     94.2       4.29        82.29
# 6   월별  07월       523       0.8      5.7     93.6       4.25        81.37
# 7   월별  08월       529       0.8      7.0     92.2       4.23        80.63
# 8   월별  09월       510       0.7      2.8     96.5       4.45        86.29
# 9   월별  10월       529       0.0      4.4     95.6       4.33        83.18
# 10  월별  11월       487       0.5      3.7     95.8       4.32        83.08
# 11  월별  12월       477       0.2      6.2     93.5       4.20        79.99

# %% [markdown]
# ## 관광지매력도 만족도

# %%
placecharm_2018 = pd.read_excel(DATA_PATH + 'plus/2018_관광지매력도.xlsx',
                            skiprows=1,
                            skipfooter=1)
placecharm_2018.head()
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족  ①+②     ③  \
# 0       [전체]        NaN  6115      0.1   0.6   5.2  40.1    54.0  0.7   5.2
# 1         월별        01월   467      1.4   3.8  17.2  50.7    26.9  5.2  17.2
# 2         월별        02월   400      0.6   2.2  23.2  51.5    22.5  2.8  23.2
# 3         월별        03월   477      0.0   0.3   9.2  47.0    43.6  0.3   9.2
# 4         월별        04월   575      0.0   0.0   0.9  37.0    62.1  0.0   0.9
#
#     ④+⑤  [5점 평균]  [100점 평균]
# 0  94.1     4.47      86.82
# 1  77.6     3.98      74.50
# 2  74.0     3.93      73.30
# 3  90.6     4.34      83.47
# 4  99.1     4.61      90.30

# %%
placecharm_2018 = placecharm_2018.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족'], axis = 1)
placecharm_2018.head()
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①+②     ③   ④+⑤  [5점 평균]  [100점 평균]
# 0       [전체]        NaN  6115  0.7   5.2  94.1     4.47      86.82
# 1         월별        01월   467  5.2  17.2  77.6     3.98      74.50
# 2         월별        02월   400  2.8  23.2  74.0     3.93      73.30
# 3         월별        03월   477  0.3   9.2  90.6     4.34      83.47
# 4         월별        04월   575  0.0   0.9  99.1     4.61      90.30

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '관광지매력 사례수',
           '①+②' : '관광지매력 불만족',
           '③' : '관광지매력 보통',
           '④+⑤' : '관광지매력 만족',
           '[5점 평균]' : '관광지매력 5점평균',
            '[100점 평균]' : '관광지매력 100점평균'
           }
placecharm_2018 = placecharm_2018.rename(columns = columns)
placecharm_2018.head()
# Out:
#      분류 세부분류  관광지매력 사례수  관광지매력 불만족  관광지매력 보통  관광지매력 만족  관광지매력 5점평균  \
# 0  [전체]  NaN       6115        0.7       5.2      94.1        4.47
# 1    월별  01월        467        5.2      17.2      77.6        3.98
# 2    월별  02월        400        2.8      23.2      74.0        3.93
# 3    월별  03월        477        0.3       9.2      90.6        4.34
# 4    월별  04월        575        0.0       0.9      99.1        4.61
#
#    관광지매력 100점평균
# 0         86.82
# 1         74.50
# 2         73.30
# 3         83.47
# 4         90.30

# %%
placecharm_2018 = placecharm_2018.iloc[1:13, :].reset_index(drop=True)
placecharm_2018
# Out:
#     분류 세부분류  관광지매력 사례수  관광지매력 불만족  관광지매력 보통  관광지매력 만족  관광지매력 5점평균  \
# 0   월별  01월        467        5.2      17.2      77.6        3.98
# 1   월별  02월        400        2.8      23.2      74.0        3.93
# 2   월별  03월        477        0.3       9.2      90.6        4.34
# 3   월별  04월        575        0.0       0.9      99.1        4.61
# 4   월별  05월        566        0.0       0.4      99.6        4.67
# 5   월별  06월        554        0.2       2.1      97.7        4.59
# 6   월별  07월        526        0.0       2.6      97.4        4.59
# 7   월별  08월        538        0.3       3.4      96.4        4.56
# 8   월별  09월        515        0.0       0.8      99.2        4.63
# 9   월별  10월        530        0.2       3.1      96.7        4.52
# 10  월별  11월        489        0.2       3.3      96.5        4.51
# 11  월별  12월        478        0.5       2.5      97.1        4.53
#
#     관광지매력 100점평균
# 0          74.50
# 1          73.30
# 2          83.47
# 3          90.30
# ...

# %% [markdown]
# ## 교통정보 서비스
# - 2018/2019의 경우 교통 표지판 서비스로 되어있었으나 이후 교통정보 서비스 항목으로 바뀌어 통합하혀 전처리할 계획

# %%
trafficinfo_2018 = pd.read_excel(DATA_PATH + 'plus/2018_교통정보서비스.xlsx',
                            skiprows=1,
                            skipfooter=1)
trafficinfo_2018.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족   ①+②     ③  \
# 0       [전체]        NaN  5472      0.7   3.0  12.3  54.3    29.7   3.7  12.3
# 1         월별        01월   437      3.7  10.1  38.3  37.6    10.2  13.9  38.3
#
#     ④+⑤  [5점 평균]  [100점 평균]
# 0  84.0     4.09      77.34
# 1  47.8     3.40      60.10

# %%
trafficinfo_2018 = trafficinfo_2018.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족'], axis = 1)
trafficinfo_2018.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수   ①+②     ③   ④+⑤  [5점 평균]  [100점 평균]
# 0       [전체]        NaN  5472   3.7  12.3  84.0     4.09      77.34
# 1         월별        01월   437  13.9  38.3  47.8     3.40      60.10

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '교통정보 사례수',
           '①+②' : '교통정보 불만족',
           '③' : '교통정보 보통',
           '④+⑤' : '교통정보 만족',
           '[5점 평균]' : '교통정보 5점평균',
            '[100점 평균]' : '교통정보 100점평균'
           }
trafficinfo_2018 = trafficinfo_2018.rename(columns = columns)
trafficinfo_2018.head()
# Out:
#      분류 세부분류  교통정보 사례수  교통정보 불만족  교통정보 보통  교통정보 만족  교통정보 5점평균  교통정보 100점평균
# 0  [전체]  NaN      5472       3.7     12.3     84.0       4.09        77.34
# 1    월별  01월       437      13.9     38.3     47.8       3.40        60.10
# 2    월별  02월       369      16.3     36.9     46.8       3.37        59.30
# 3    월별  03월       441       5.8     19.2     75.0       3.88        71.98
# 4    월별  04월       559       0.5      7.6     91.9       4.24        80.93

# %%
trafficinfo_2018 = trafficinfo_2018.iloc[1:13, :].reset_index(drop=True)
trafficinfo_2018
# Out:
#     분류 세부분류  교통정보 사례수  교통정보 불만족  교통정보 보통  교통정보 만족  교통정보 5점평균  교통정보 100점평균
# 0   월별  01월       437      13.9     38.3     47.8       3.40        60.10
# 1   월별  02월       369      16.3     36.9     46.8       3.37        59.30
# 2   월별  03월       441       5.8     19.2     75.0       3.88        71.98
# 3   월별  04월       559       0.5      7.6     91.9       4.24        80.93
# 4   월별  05월       559       0.9      3.1     96.0       4.17        79.29
# 5   월별  06월       519       1.7      6.5     91.7       4.20        79.98
# 6   월별  07월       476       3.4      7.2     89.4       4.24        81.02
# 7   월별  08월       396       1.6      7.1     91.3       4.23        80.72
# 8   월별  09월       397       0.6      4.6     94.8       4.46        86.50
# 9   월별  10월       451       1.1      7.3     91.6       4.31        82.69
# 10  월별  11월       397       0.6     11.0     88.4       4.28        81.97
# 11  월별  12월       471       1.3      7.4     91.3       4.19        79.65

# %% [markdown]
# ## 방문관광지 편의성 만족도

# %%
conv_2018 = pd.read_excel(DATA_PATH + 'plus/2018_방문관광지편의성.xlsx',
                            skiprows=1,
                            skipfooter=1)
conv_2018.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족  ①+②     ③  \
# 0       [전체]        NaN  6117      0.1   0.7   9.2  48.3    41.7  0.8   9.2
# 1         월별        01월   466      1.1   3.9  31.3  47.7    16.0  5.0  31.3
#
#     ④+⑤  [5점 평균]  [100점 평균]
# 0  90.0     4.31      82.69
# 1  63.7     3.74      68.40

# %%
conv_2018 = conv_2018.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족'], axis = 1)
conv_2018.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①+②     ③   ④+⑤  [5점 평균]  [100점 평균]
# 0       [전체]        NaN  6117  0.8   9.2  90.0     4.31      82.69
# 1         월별        01월   466  5.0  31.3  63.7     3.74      68.40

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '관광지편의성 사례수',
           '①+②' : '관광지편의성 불만족',
           '③' : '관광지편의성 보통',
           '④+⑤' : '관광지편의성 만족',
           '[5점 평균]' : '관광지편의성 5점평균',
            '[100점 평균]' : '관광지편의성 100점평균'
           }
conv_2018 = conv_2018.rename(columns = columns)
conv_2018.head()
# Out:
#      분류 세부분류  관광지편의성 사례수  관광지편의성 불만족  관광지편의성 보통  관광지편의성 만족  관광지편의성 5점평균  \
# 0  [전체]  NaN        6117         0.8        9.2       90.0         4.31
# 1    월별  01월         466         5.0       31.3       63.7         3.74
# 2    월별  02월         402         2.6       34.4       62.9         3.73
# 3    월별  03월         477         0.5       16.0       83.4         4.13
# 4    월별  04월         575         0.1        5.6       94.3         4.41
#
#    관광지편의성 100점평균
# 0          82.69
# 1          68.40
# 2          68.34
# 3          78.35
# 4          85.23

# %%
conv_2018 = conv_2018.iloc[1:13, :].reset_index(drop=True)
conv_2018
# Out:
#     분류 세부분류  관광지편의성 사례수  관광지편의성 불만족  관광지편의성 보통  관광지편의성 만족  관광지편의성 5점평균  \
# 0   월별  01월         466         5.0       31.3       63.7         3.74
# 1   월별  02월         402         2.6       34.4       62.9         3.73
# 2   월별  03월         477         0.5       16.0       83.4         4.13
# 3   월별  04월         575         0.1        5.6       94.3         4.41
# 4   월별  05월         567         0.3        1.5       98.2         4.52
# 5   월별  06월         554         0.3        5.1       94.7         4.40
# 6   월별  07월         525         0.5        5.2       94.3         4.44
# 7   월별  08월         538         0.5        5.4       94.0         4.37
# 8   월별  09월         513         0.0        2.0       98.0         4.53
# 9   월별  10월         530         0.2        3.7       96.0         4.42
# 10  월별  11월         489         0.7        5.0       94.3         4.44
# 11  월별  12월         479         0.5        4.0       95.6         4.34
#
#     관광지편의성 100점평균
# 0           68.40
# ...

# %% [markdown]
# ## 쇼핑 만족도

# %%
shopping_2018 = pd.read_excel(DATA_PATH + 'plus/2018_쇼핑.xlsx',
                            skiprows=1,
                            skipfooter=1)
shopping_2018.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족  ①+②     ③  \
# 0       [전체]        NaN  4854      0.3   1.5  17.1  54.2    26.9  1.8  17.1
# 1         월별        01월   389      2.2   6.6  41.8  33.5    15.9  8.8  41.8
#
#     ④+⑤  [5점 평균]  [100점 평균]
# 0  81.2     4.06      76.52
# 1  49.4     3.54      63.56

# %%
shopping_2018 = shopping_2018.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족'], axis = 1)
shopping_2018.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①+②     ③   ④+⑤  [5점 평균]  [100점 평균]
# 0       [전체]        NaN  4854  1.8  17.1  81.2     4.06      76.52
# 1         월별        01월   389  8.8  41.8  49.4     3.54      63.56

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '쇼핑 사례수',
           '①+②' : '쇼핑 불만족',
           '③' : '쇼핑 보통',
           '④+⑤' : '쇼핑 만족',
           '[5점 평균]' : '쇼핑 5점평균',
            '[100점 평균]' : '쇼핑 100점평균'
           }
shopping_2018 = shopping_2018.rename(columns = columns)
shopping_2018.head()
# Out:
#      분류 세부분류  쇼핑 사례수  쇼핑 불만족  쇼핑 보통  쇼핑 만족  쇼핑 5점평균  쇼핑 100점평균
# 0  [전체]  NaN    4854     1.8   17.1   81.2     4.06      76.52
# 1    월별  01월     389     8.8   41.8   49.4     3.54      63.56
# 2    월별  02월     313     4.9   42.7   52.4     3.58      64.61
# 3    월별  03월     371     2.7   27.6   69.7     3.79      69.70
# 4    월별  04월     496     1.1   13.3   85.6     4.08      76.88

# %%
shopping_2018 = shopping_2018.iloc[1:13, :].reset_index(drop=True)
shopping_2018
# Out:
#     분류 세부분류  쇼핑 사례수  쇼핑 불만족  쇼핑 보통  쇼핑 만족  쇼핑 5점평균  쇼핑 100점평균
# 0   월별  01월     389     8.8   41.8   49.4     3.54      63.56
# 1   월별  02월     313     4.9   42.7   52.4     3.58      64.61
# 2   월별  03월     371     2.7   27.6   69.7     3.79      69.70
# 3   월별  04월     496     1.1   13.3   85.6     4.08      76.88
# 4   월별  05월     437     0.6    6.8   92.6     4.27      81.65
# 5   월별  06월     406     0.1    8.9   91.0     4.25      81.21
# 6   월별  07월     334     0.4   12.0   87.6     4.24      80.88
# 7   월별  08월     419     0.6   16.6   82.8     4.08      76.97
# 8   월별  09월     443     0.8   11.8   87.4     4.29      82.23
# 9   월별  10월     430     1.1   13.4   85.5     4.08      77.10
# 10  월별  11월     397     0.6   10.3   89.1     4.20      80.00
# 11  월별  12월     421     0.6    9.2   90.2     4.17      79.32

# %% [markdown]
# ## 숙박시설 만족도

# %%
accom_2018 = pd.read_excel(DATA_PATH + 'plus/2018_숙박시설.xlsx',
                            skiprows=1,
                            skipfooter=1)
accom_2018.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족  ①+②     ③  \
# 0       [전체]        NaN  5880      0.2   0.7   5.3  49.5    44.2  0.9   5.3
# 1         월별        01월   432      1.2   2.1  19.9  51.9    25.0  3.2  19.9
#
#     ④+⑤  [5점 평균]  [100점 평균]
# 0  93.7     4.37      84.17
# 1  76.9     3.97      74.36

# %%
accom_2018 = accom_2018.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족'], axis = 1)
accom_2018.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①+②     ③   ④+⑤  [5점 평균]  [100점 평균]
# 0       [전체]        NaN  5880  0.9   5.3  93.7     4.37      84.17
# 1         월별        01월   432  3.2  19.9  76.9     3.97      74.36

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '숙박 사례수',
           '①+②' : '숙박 불만족',
           '③' : '숙박 보통',
           '④+⑤' : '숙박 만족',
           '[5점 평균]' : '숙박 5점평균',
            '[100점 평균]' : '숙박 100점평균'
           }
accom_2018 = accom_2018.rename(columns = columns)
accom_2018.head(2)
# Out:
#      분류 세부분류  숙박 사례수  숙박 불만족  숙박 보통  숙박 만족  숙박 5점평균  숙박 100점평균
# 0  [전체]  NaN    5880     0.9    5.3   93.7     4.37      84.17
# 1    월별  01월     432     3.2   19.9   76.9     3.97      74.36

# %%
accom_2018 = accom_2018.iloc[1:13, :].reset_index(drop=True)
accom_2018
# Out:
#     분류 세부분류  숙박 사례수  숙박 불만족  숙박 보통  숙박 만족  숙박 5점평균  숙박 100점평균
# 0   월별  01월     432     3.2   19.9   76.9     3.97      74.36
# 1   월별  02월     372     2.8   16.7   80.5     4.06      76.42
# 2   월별  03월     434     1.8   10.2   88.0     4.23      80.69
# 3   월별  04월     557     0.9    3.9   95.2     4.37      84.29
# 4   월별  05월     550     1.2    2.8   96.0     4.38      84.55
# 5   월별  06월     528     0.5    2.7   96.8     4.44      85.94
# 6   월별  07월     512     0.5    2.9   96.5     4.43      85.70
# 7   월별  08월     521     0.5    2.4   97.1     4.42      85.53
# 8   월별  09월     504     0.3    2.4   97.3     4.51      87.77
# 9   월별  10월     523     0.0    2.0   98.0     4.47      86.76
# 10  월별  11월     475     0.3    2.5   97.2     4.52      88.00
# 11  월별  12월     470     0.2    1.8   98.0     4.45      86.22

# %% [markdown]
# ## 여행경비 만족도

# %%
budget_2018 = pd.read_excel(DATA_PATH + 'plus/2018_여행경비.xlsx',
                            skiprows=1,
                            skipfooter=1)
budget_2018.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족   ①+②     ③  \
# 0       [전체]        NaN  6139      1.9   6.9  27.1  46.4    17.6   8.8  27.1
# 1         월별        01월   477      7.0  18.5  39.7  24.5    10.4  25.5  39.7
#
#     ④+⑤  [5점 평균]  [100점 평균]
# 0  64.1     3.71      67.75
# 1  34.9     3.13      53.19

# %%
budget_2018 = budget_2018.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족'], axis = 1)
budget_2018.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수   ①+②     ③   ④+⑤  [5점 평균]  [100점 평균]
# 0       [전체]        NaN  6139   8.8  27.1  64.1     3.71      67.75
# 1         월별        01월   477  25.5  39.7  34.9     3.13      53.19

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '여행경비 사례수',
           '①+②' : '여행경비 불만족',
           '③' : '여행경비 보통',
           '④+⑤' : '여행경비 만족',
           '[5점 평균]' : '여행경비 5점평균',
            '[100점 평균]' : '여행경비 100점평균'
           }
budget_2018 = budget_2018.rename(columns = columns)
budget_2018.head(2)
# Out:
#      분류 세부분류  여행경비 사례수  여행경비 불만족  여행경비 보통  여행경비 만족  여행경비 5점평균  여행경비 100점평균
# 0  [전체]  NaN      6139       8.8     27.1     64.1       3.71        67.75
# 1    월별  01월       477      25.5     39.7     34.9       3.13        53.19

# %%
budget_2018 = budget_2018.iloc[1:13, :].reset_index(drop=True)
budget_2018
# Out:
#     분류 세부분류  여행경비 사례수  여행경비 불만족  여행경비 보통  여행경비 만족  여행경비 5점평균  여행경비 100점평균
# 0   월별  01월       477      25.5     39.7     34.9       3.13        53.19
# 1   월별  02월       410      25.3     44.8     29.9       3.03        50.64
# 2   월별  03월       479      18.4     29.8     51.7       3.42        60.54
# 3   월별  04월       575       4.5     22.8     72.7       3.82        70.61
# 4   월별  05월       567       3.1     10.7     86.2       4.02        75.39
# 5   월별  06월       553       5.5     22.3     72.2       3.87        71.74
# 6   월별  07월       527       5.6     23.8     70.5       3.87        71.65
# 7   월별  08월       540       7.1     31.0     61.8       3.71        67.67
# 8   월별  09월       516       5.7     24.5     69.8       3.95        73.84
# 9   월별  10월       528       6.0     28.7     65.3       3.77        69.32
# 10  월별  11월       489       3.0     27.4     69.6       3.84        70.97
# 11  월별  12월       478       2.3     26.7     71.0       3.85        71.16

# %% [markdown]
# ## 음식 만족도

# %%
food_2018 = pd.read_excel(DATA_PATH + 'plus/2018_음식.xlsx',
                            skiprows=1,
                            skipfooter=1)
food_2018.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족  ①+②     ③  \
# 0       [전체]        NaN  5954      0.3   1.4   9.4  55.3    33.5  1.7   9.4
# 1         월별        01월   454      1.2   4.9  23.7  47.8    22.5  6.1  23.7
#
#     ④+⑤  [5점 평균]  [100점 평균]
# 0  88.8     4.20      80.07
# 1  70.3     3.86      71.38

# %%
food_2018 = food_2018.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족'], axis = 1)
food_2018.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①+②     ③   ④+⑤  [5점 평균]  [100점 평균]
# 0       [전체]        NaN  5954  1.7   9.4  88.8     4.20      80.07
# 1         월별        01월   454  6.1  23.7  70.3     3.86      71.38

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '음식 사례수',
           '①+②' : '음식 불만족',
           '③' : '음식 보통',
           '④+⑤' : '음식 만족',
           '[5점 평균]' : '음식 5점평균',
            '[100점 평균]' : '음식 100점평균'
           }
food_2018 = food_2018.rename(columns = columns)
food_2018.head(2)
# Out:
#      분류 세부분류  음식 사례수  음식 불만족  음식 보통  음식 만족  음식 5점평균  음식 100점평균
# 0  [전체]  NaN    5954     1.7    9.4   88.8     4.20      80.07
# 1    월별  01월     454     6.1   23.7   70.3     3.86      71.38

# %%
food_2018 = food_2018.iloc[1:13, :].reset_index(drop=True)
food_2018
# Out:
#     분류 세부분류  음식 사례수  음식 불만족  음식 보통  음식 만족  음식 5점평균  음식 100점평균
# 0   월별  01월     454     6.1   23.7   70.3     3.86      71.38
# 1   월별  02월     398     5.2   20.8   74.0     3.90      72.53
# 2   월별  03월     469     2.2   13.7   84.1     4.07      76.64
# 3   월별  04월     551     2.0   10.1   87.9     4.11      77.73
# 4   월별  05월     526     0.8    4.2   95.1     4.31      82.68
# 5   월별  06월     536     0.8    7.6   91.7     4.28      81.95
# 6   월별  07월     517     1.5    5.5   93.1     4.27      81.68
# 7   월별  08월     526     0.3    6.2   93.5     4.30      82.48
# 8   월별  09월     508     1.2    4.9   93.9     4.39      84.74
# 9   월별  10월     523     0.9    8.6   90.5     4.25      81.22
# 10  월별  11월     479     0.7    5.4   93.9     4.36      84.05
# 11  월별  12월     469     0.2    7.3   92.5     4.24      81.08

# %% [markdown]
# ## 제주도 내 대중교통 만족도

# %%
pt_2018 = pd.read_excel(DATA_PATH + 'plus/2018_제주도내대중교통.xlsx',
                            skiprows=1,
                            skipfooter=1)
pt_2018.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1  사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족   ①+②     ③  \
# 0       [전체]        NaN  679      4.9  15.7  36.8  33.4     9.2  20.6  36.8
# 1         월별        01월  135      3.8  13.0  41.2  33.4     8.6  16.9  41.2
#
#     ④+⑤  [5점 평균]  [100점 평균]
# 0  42.6     3.26      56.56
# 1  42.0     3.30      57.46

# %%
pt_2018 = pt_2018.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족'], axis = 1)
pt_2018.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1  사례수   ①+②     ③   ④+⑤  [5점 평균]  [100점 평균]
# 0       [전체]        NaN  679  20.6  36.8  42.6     3.26      56.56
# 1         월별        01월  135  16.9  41.2  42.0     3.30      57.46

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '대중교통 사례수',
           '①+②' : '대중교통 불만족',
           '③' : '대중교통 보통',
           '④+⑤' : '대중교통 만족',
           '[5점 평균]' : '대중교통 5점평균',
            '[100점 평균]' : '대중교통 100점평균'
           }
pt_2018 = pt_2018.rename(columns = columns)
pt_2018.head(2)
# Out:
#      분류 세부분류  대중교통 사례수  대중교통 불만족  대중교통 보통  대중교통 만족  대중교통 5점평균  대중교통 100점평균
# 0  [전체]  NaN       679      20.6     36.8     42.6       3.26        56.56
# 1    월별  01월       135      16.9     41.2     42.0       3.30        57.46

# %%
pt_2018 = pt_2018.iloc[1:13, :].reset_index(drop=True)
pt_2018
# Out:
#     분류 세부분류  대중교통 사례수  대중교통 불만족  대중교통 보통  대중교통 만족  대중교통 5점평균  대중교통 100점평균
# 0   월별  01월       135      16.9     41.2     42.0       3.30        57.46
# 1   월별  02월       168      27.7     36.0     36.3       3.09        52.25
# 2   월별  03월        89      28.7     28.1     43.2       3.14        53.53
# 3   월별  04월        48      11.3     44.6     44.2       3.38        59.58
# 4   월별  05월        44      11.4     37.6     51.0       3.49        62.28
# 5   월별  06월        17      14.5     47.7     37.9       3.16        54.04
# 6   월별  07월        46      26.4     32.0     41.6       3.22        55.44
# 7   월별  08월        42      17.1     31.4     51.4       3.40        60.00
# 8   월별  09월        19       6.4     51.4     42.2       3.45        61.23
# 9   월별  10월        20      25.2     19.1     55.8       3.43        60.71
# 10  월별  11월        22      20.2     37.7     42.1       3.28        57.05
# 11  월별  12월        30       7.8     45.1     47.1       3.59        64.82

# %% [markdown]
# ## 지역주민 친절 만족도

# %%
kind_2018 = pd.read_excel(DATA_PATH + 'plus/2018_지역주민친절.xlsx',
                            skiprows=1,
                            skipfooter=1)
kind_2018.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족  ①+②     ③  \
# 0       [전체]        NaN  5980      0.6   2.0  15.0  55.8    26.6  2.6  15.0
# 1         월별        01월   457      2.2   6.5  29.9  39.8    21.6  8.7  29.9
#
#     ④+⑤  [5점 평균]  [100점 평균]
# 0  82.4     4.06      76.46
# 1  61.4     3.72      68.02

# %%
kind_2018 = kind_2018.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족'], axis = 1)
kind_2018.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①+②     ③   ④+⑤  [5점 평균]  [100점 평균]
# 0       [전체]        NaN  5980  2.6  15.0  82.4     4.06      76.46
# 1         월별        01월   457  8.7  29.9  61.4     3.72      68.02

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '주민친절 사례수',
           '①+②' : '주민친절 불만족',
           '③' : '주민친절 보통',
           '④+⑤' : '주민친절 만족',
           '[5점 평균]' : '주민친절 5점평균',
            '[100점 평균]' : '주민친절 100점평균'
           }
kind_2018 = kind_2018.rename(columns = columns)
kind_2018.head(2)
# Out:
#      분류 세부분류  주민친절 사례수  주민친절 불만족  주민친절 보통  주민친절 만족  주민친절 5점평균  주민친절 100점평균
# 0  [전체]  NaN      5980       2.6     15.0     82.4       4.06        76.46
# 1    월별  01월       457       8.7     29.9     61.4       3.72        68.02

# %%
kind_2018 = kind_2018.iloc[1:13, :].reset_index(drop=True)
kind_2018
# Out:
#     분류 세부분류  주민친절 사례수  주민친절 불만족  주민친절 보통  주민친절 만족  주민친절 5점평균  주민친절 100점평균
# 0   월별  01월       457       8.7     29.9     61.4       3.72        68.02
# 1   월별  02월       393       6.7     32.7     60.6       3.72        68.01
# 2   월별  03월       457       3.7     23.0     73.3       3.90        72.39
# 3   월별  04월       572       1.4      7.3     91.4       4.18        79.42
# 4   월별  05월       556       1.2      4.6     94.2       4.21        80.25
# 5   월별  06월       553       2.1     11.9     85.9       4.13        78.13
# 6   월별  07월       508       3.3     17.7     79.1       4.05        76.22
# 7   월별  08월       527       1.9     14.5     83.6       4.05        76.28
# 8   월별  09월       495       0.5      6.7     92.8       4.36        84.07
# 9   월별  10월       530       1.9     15.9     82.2       4.03        75.68
# 10  월별  11월       474       1.0     10.4     88.6       4.15        78.81
# 11  월별  12월       460       0.3     13.6     86.0       4.06        76.59

# %% [markdown]
# ## 치안 만족도

# %%
safety_2018 = pd.read_excel(DATA_PATH + 'plus/2018_치안.xlsx',
                            skiprows=1,
                            skipfooter=1)
safety_2018.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족  ①+②     ③  \
# 0       [전체]        NaN  6140      0.2   0.6   7.1  65.9    26.2  0.8   7.1
# 1         월별        01월   481      1.3   2.4  24.7  46.1    25.5  3.7  24.7
#
#     ④+⑤  [5점 평균]  [100점 평균]
# 0  92.1     4.17      79.33
# 1  71.6     3.92      73.02

# %%
safety_2018 = safety_2018.drop(['①매우 불만족',	'②불만족',	'③보통',	'④만족',	'⑤매우 만족'], axis = 1)
safety_2018.head(2)
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①+②     ③   ④+⑤  [5점 평균]  [100점 평균]
# 0       [전체]        NaN  6140  0.8   7.1  92.1     4.17      79.33
# 1         월별        01월   481  3.7  24.7  71.6     3.92      73.02

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '사례수' : '치안 사례수',
           '①+②' : '치안 불만족',
           '③' : '치안 보통',
           '④+⑤' : '치안 만족',
           '[5점 평균]' : '치안 5점평균',
            '[100점 평균]' : '치안 100점평균'
           }
safety_2018 = safety_2018.rename(columns = columns)
safety_2018.head(2)
# Out:
#      분류 세부분류  치안 사례수  치안 불만족  치안 보통  치안 만족  치안 5점평균  치안 100점평균
# 0  [전체]  NaN    6140     0.8    7.1   92.1     4.17      79.33
# 1    월별  01월     481     3.7   24.7   71.6     3.92      73.02

# %%
safety_2018 = safety_2018.iloc[1:13, :].reset_index(drop=True)
safety_2018
# Out:
#     분류 세부분류  치안 사례수  치안 불만족  치안 보통  치안 만족  치안 5점평균  치안 100점평균
# 0   월별  01월     481     3.7   24.7   71.6     3.92      73.02
# 1   월별  02월     405     2.3   29.9   67.8     3.90      72.38
# 2   월별  03월     476     1.6   11.0   87.4     4.13      78.36
# 3   월별  04월     576     0.2    3.4   96.4     4.23      80.74
# 4   월별  05월     567     0.2    0.9   98.9     4.23      80.87
# 5   월별  06월     552     0.3    2.7   97.0     4.25      81.25
# 6   월별  07월     528     0.2    4.9   94.8     4.24      80.91
# 7   월별  08월     539     0.7    5.0   94.3     4.14      78.60
# 8   월별  09월     516     0.2    1.1   98.7     4.37      84.30
# 9   월별  10월     530     0.5    1.9   97.7     4.20      80.00
# 10  월별  11월     489     0.2    4.4   95.4     4.19      79.79
# 11  월별  12월     479     0.0    2.8   97.2     4.17      79.28

# %% [markdown]
# ## 통합

# %%
re = pd.merge(tourinfo_2018, placecharm_2018, on=['분류', '세부분류'])

# %%
re1 = pd.merge(re, trafficinfo_2018, on=['분류', '세부분류'])
re1.head(2)
# Out:
#    분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균  \
# 0  월별  01월       429       7.4     38.6     54.0       3.62        65.39
# 1  월별  02월       367       4.8     40.6     54.6       3.61        65.37
#
#    관광지매력 사례수  관광지매력 불만족  관광지매력 보통  관광지매력 만족  관광지매력 5점평균  관광지매력 100점평균  \
# 0        467        5.2      17.2      77.6        3.98          74.5
# 1        400        2.8      23.2      74.0        3.93          73.3
#
#    교통정보 사례수  교통정보 불만족  교통정보 보통  교통정보 만족  교통정보 5점평균  교통정보 100점평균
# 0       437      13.9     38.3     47.8       3.40         60.1
# 1       369      16.3     36.9     46.8       3.37         59.3

# %%
re2 = pd.merge(re1, conv_2018, on=['분류', '세부분류'])
re2.head(2)
# Out:
#    분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균  \
# 0  월별  01월       429       7.4     38.6     54.0       3.62        65.39
# 1  월별  02월       367       4.8     40.6     54.6       3.61        65.37
#
#    관광지매력 사례수  관광지매력 불만족  ...  교통정보 보통  교통정보 만족  교통정보 5점평균  교통정보 100점평균  \
# 0        467        5.2  ...     38.3     47.8       3.40         60.1
# 1        400        2.8  ...     36.9     46.8       3.37         59.3
#
#    관광지편의성 사례수  관광지편의성 불만족  관광지편의성 보통  관광지편의성 만족  관광지편의성 5점평균  관광지편의성 100점평균
# 0         466         5.0       31.3       63.7         3.74          68.40
# 1         402         2.6       34.4       62.9         3.73          68.34
#
# [2 rows x 26 columns]

# %%
re3 = pd.merge(re2, shopping_2018, on=['분류', '세부분류'])
re3
# Out:
#     분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균  \
# 0   월별  01월       429       7.4     38.6     54.0       3.62        65.39
# 1   월별  02월       367       4.8     40.6     54.6       3.61        65.37
# 2   월별  03월       462       1.4     22.5     76.0       3.98        74.50
# 3   월별  04월       574       0.5      5.5     94.0       4.34        83.59
# 4   월별  05월       563       0.2      1.4     98.4       4.35        83.78
# 5   월별  06월       554       0.9      4.8     94.2       4.29        82.29
# 6   월별  07월       523       0.8      5.7     93.6       4.25        81.37
# 7   월별  08월       529       0.8      7.0     92.2       4.23        80.63
# 8   월별  09월       510       0.7      2.8     96.5       4.45        86.29
# 9   월별  10월       529       0.0      4.4     95.6       4.33        83.18
# 10  월별  11월       487       0.5      3.7     95.8       4.32        83.08
# 11  월별  12월       477       0.2      6.2     93.5       4.20        79.99
#
# ...

# %%
re4 = pd.merge(re3, accom_2018, on=['분류', '세부분류'])
re4.head(2)
# Out:
#    분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균  \
# 0  월별  01월       429       7.4     38.6     54.0       3.62        65.39
# 1  월별  02월       367       4.8     40.6     54.6       3.61        65.37
#
#    관광지매력 사례수  관광지매력 불만족  ...  쇼핑 보통  쇼핑 만족  쇼핑 5점평균  쇼핑 100점평균  숙박 사례수  \
# 0        467        5.2  ...   41.8   49.4     3.54      63.56     432
# 1        400        2.8  ...   42.7   52.4     3.58      64.61     372
#
#    숙박 불만족  숙박 보통  숙박 만족  숙박 5점평균  숙박 100점평균
# 0     3.2   19.9   76.9     3.97      74.36
# 1     2.8   16.7   80.5     4.06      76.42
#
# [2 rows x 38 columns]

# %%
re5 = pd.merge(re4, budget_2018, on=['분류', '세부분류'])
re5.head(2)
# Out:
#    분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균  \
# 0  월별  01월       429       7.4     38.6     54.0       3.62        65.39
# 1  월별  02월       367       4.8     40.6     54.6       3.61        65.37
#
#    관광지매력 사례수  관광지매력 불만족  ...  숙박 보통  숙박 만족  숙박 5점평균  숙박 100점평균  여행경비 사례수  \
# 0        467        5.2  ...   19.9   76.9     3.97      74.36       477
# 1        400        2.8  ...   16.7   80.5     4.06      76.42       410
#
#    여행경비 불만족  여행경비 보통  여행경비 만족  여행경비 5점평균  여행경비 100점평균
# 0      25.5     39.7     34.9       3.13        53.19
# 1      25.3     44.8     29.9       3.03        50.64
#
# [2 rows x 44 columns]

# %%
re6 = pd.merge(re5, food_2018, on=['분류', '세부분류'])
re6.head(2)
# Out:
#    분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균  \
# 0  월별  01월       429       7.4     38.6     54.0       3.62        65.39
# 1  월별  02월       367       4.8     40.6     54.6       3.61        65.37
#
#    관광지매력 사례수  관광지매력 불만족  ...  여행경비 보통  여행경비 만족  여행경비 5점평균  여행경비 100점평균  \
# 0        467        5.2  ...     39.7     34.9       3.13        53.19
# 1        400        2.8  ...     44.8     29.9       3.03        50.64
#
#    음식 사례수  음식 불만족  음식 보통  음식 만족  음식 5점평균  음식 100점평균
# 0     454     6.1   23.7   70.3     3.86      71.38
# 1     398     5.2   20.8   74.0     3.90      72.53
#
# [2 rows x 50 columns]

# %%
re7 = pd.merge(re6, pt_2018, on=['분류', '세부분류'])
re7.head(2)
# Out:
#    분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균  \
# 0  월별  01월       429       7.4     38.6     54.0       3.62        65.39
# 1  월별  02월       367       4.8     40.6     54.6       3.61        65.37
#
#    관광지매력 사례수  관광지매력 불만족  ...  음식 보통  음식 만족  음식 5점평균  음식 100점평균  대중교통 사례수  \
# 0        467        5.2  ...   23.7   70.3     3.86      71.38       135
# 1        400        2.8  ...   20.8   74.0     3.90      72.53       168
#
#    대중교통 불만족  대중교통 보통  대중교통 만족  대중교통 5점평균  대중교통 100점평균
# 0      16.9     41.2     42.0       3.30        57.46
# 1      27.7     36.0     36.3       3.09        52.25
#
# [2 rows x 56 columns]

# %%
re8 = pd.merge(re7, kind_2018, on=['분류', '세부분류'])
re7.head(2)
# Out:
#    분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균  \
# 0  월별  01월       429       7.4     38.6     54.0       3.62        65.39
# 1  월별  02월       367       4.8     40.6     54.6       3.61        65.37
#
#    관광지매력 사례수  관광지매력 불만족  ...  음식 보통  음식 만족  음식 5점평균  음식 100점평균  대중교통 사례수  \
# 0        467        5.2  ...   23.7   70.3     3.86      71.38       135
# 1        400        2.8  ...   20.8   74.0     3.90      72.53       168
#
#    대중교통 불만족  대중교통 보통  대중교통 만족  대중교통 5점평균  대중교통 100점평균
# 0      16.9     41.2     42.0       3.30        57.46
# 1      27.7     36.0     36.3       3.09        52.25
#
# [2 rows x 56 columns]

# %%
result_2018 = pd.merge(re8, safety_2018, on=['분류', '세부분류'])
result_2018.head(2)
# Out:
#    분류 세부분류  관광정보 사례수  관광정보 불만족  관광정보 보통  관광정보 만족  관광정보 5점평균  관광정보 100점평균  \
# 0  월별  01월       429       7.4     38.6     54.0       3.62        65.39
# 1  월별  02월       367       4.8     40.6     54.6       3.61        65.37
#
#    관광지매력 사례수  관광지매력 불만족  ...  주민친절 보통  주민친절 만족  주민친절 5점평균  주민친절 100점평균  \
# 0        467        5.2  ...     29.9     61.4       3.72        68.02
# 1        400        2.8  ...     32.7     60.6       3.72        68.01
#
#    치안 사례수  치안 불만족  치안 보통  치안 만족  치안 5점평균  치안 100점평균
# 0     481     3.7   24.7   71.6     3.92      73.02
# 1     405     2.3   29.9   67.8     3.90      72.38
#
# [2 rows x 68 columns]

# %%
result_2018.to_csv("result_2018.csv", index = True)
