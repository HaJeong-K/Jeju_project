# %% [markdown]
# # 2020 설문조사 전처리
# - 본격적으로 코로나 사태가 터지기 시작한 년도라 지난 년도들 대비 데이터 수 대폭 감소/데이터 누락이 있음
# - 여행 목적, 정보 출처와 원하는 정보, 제주에서의 활동, 만족도 관련, 이미지 등 위주로 정리
# - 남긴 분류는 월별, 성별, 나이
# - 삭제 항목 : 거주지, 여행 목적, 여행형태, 방문횟수, 이용 교통수단

# %% [markdown]
# ## 구글 드라이브, 라이브러리

# %%
import pandas as pd
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 여행목적 1순위

# %%
DATA_PATH = '/content/drive/MyDrive/Colab Notebooks/jeju/'
purpose_2020 = pd.read_excel(DATA_PATH + '2020/03 제주여행목적 1순위.xlsx',
                            skiprows=1,
                            skipfooter=1)
purpose_2020.head()
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  여가, 위락, 휴식   쇼핑  레저/스포츠  친구/친지 방문  뷰티, 의료 관광  \
# 0       [전체]        NaN  3483        82.8  0.6     2.7       3.6        0.1
# 1         구분     01-02월   928        85.7  0.2     0.5       4.1        0.1
# 2         구분     08-12월  2555        81.7  0.7     3.5       3.4        0.2
# 3         월별        01월   602        83.7  0.2     0.7       4.6        0.0
# 4         월별        02월   327        89.5  0.2     0.2       3.3        0.2
#
#    직장 인센티브 여행  도보여행(올레길 등)  종교 및 순례  사업 또는 산업시찰 활동  신혼여행  교육여행(수학여행 등)  \
# 0         0.5          4.4      0.1            1.4   1.8           0.1
# 1         0.4          2.2      0.1            3.0   0.0           0.0
# 2         0.5          5.2      0.1            0.8   2.4           0.1
# 3         0.7          2.1      0.2            2.7   0.0           0.0
# 4         0.0          2.3      0.0            3.4   0.0           0.0
#
#    학술 및 세미나 활동   기타
# 0          1.2  0.8
# 1          2.3  1.2
# ...

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           }
purpose_2020 = purpose_2020.rename(columns = columns)
purpose_2020.head()
# Out:
#      분류    세부분류   사례수  여가, 위락, 휴식   쇼핑  레저/스포츠  친구/친지 방문  뷰티, 의료 관광  \
# 0  [전체]     NaN  3483        82.8  0.6     2.7       3.6        0.1
# 1    구분  01-02월   928        85.7  0.2     0.5       4.1        0.1
# 2    구분  08-12월  2555        81.7  0.7     3.5       3.4        0.2
# 3    월별     01월   602        83.7  0.2     0.7       4.6        0.0
# 4    월별     02월   327        89.5  0.2     0.2       3.3        0.2
#
#    직장 인센티브 여행  도보여행(올레길 등)  종교 및 순례  사업 또는 산업시찰 활동  신혼여행  교육여행(수학여행 등)  \
# 0         0.5          4.4      0.1            1.4   1.8           0.1
# 1         0.4          2.2      0.1            3.0   0.0           0.0
# 2         0.5          5.2      0.1            0.8   2.4           0.1
# 3         0.7          2.1      0.2            2.7   0.0           0.0
# 4         0.0          2.3      0.0            3.4   0.0           0.0
#
#    학술 및 세미나 활동   기타
# 0          1.2  0.8
# 1          2.3  1.2
# 2          0.8  0.7
# 3          3.3  1.8
# 4          0.5  0.2

# %%
purpose_2020.set_index(purpose_2020.columns[0], inplace=True)
new_index_name='분류'
drop_rows = ['거주지', '여행 목적', '여행형태', '방문횟수', '이용 교통수단']
purpose_2020_= purpose_2020.drop(drop_rows)
purpose_2020_.head()
# Out:
#         세부분류   사례수  여가, 위락, 휴식   쇼핑  레저/스포츠  친구/친지 방문  뷰티, 의료 관광  직장 인센티브 여행  \
# 분류
# [전체]     NaN  3483        82.8  0.6     2.7       3.6        0.1         0.5
# 구분    01-02월   928        85.7  0.2     0.5       4.1        0.1         0.4
# 구분    08-12월  2555        81.7  0.7     3.5       3.4        0.2         0.5
# 월별       01월   602        83.7  0.2     0.7       4.6        0.0         0.7
# 월별       02월   327        89.5  0.2     0.2       3.3        0.2         0.0
#
#       도보여행(올레길 등)  종교 및 순례  사업 또는 산업시찰 활동  신혼여행  교육여행(수학여행 등)  학술 및 세미나 활동  \
# 분류
# [전체]          4.4      0.1            1.4   1.8           0.1          1.2
# 구분            2.2      0.1            3.0   0.0           0.0          2.3
# 구분            5.2      0.1            0.8   2.4           0.1          0.8
# 월별            2.1      0.2            2.7   0.0           0.0          3.3
# 월별            2.3      0.0            3.4   0.0           0.0          0.5
#
#        기타
# 분류
# [전체]  0.8
# 구분    1.2
# ...

# %% [markdown]
# ## 여행 고려 요인 1순위

# %%
consider_2020 = pd.read_excel(DATA_PATH + '2020/04 제주여행 고려요인 1순위.xlsx',
                            skiprows=1,
                            skipfooter=1)
consider_2020.head()
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  자연경관 감상  휴양/휴식  역사/문화유적/전통문화 체험  음식/미식 탐방   쇼핑  \
# 0       [전체]        NaN  3483     43.5   34.3              0.8       8.6  0.5
# 1         구분     01-02월   928     56.0   27.4              0.9       5.6  0.0
# 2         구분     08-12월  2555     38.9   36.8              0.8       9.7  0.6
# 3         월별        01월   602     56.5   25.8              0.9       5.4  0.0
# 4         월별        02월   327     55.0   30.3              0.8       5.9  0.0
#
#    여행비용  자국과의 이동 거리  안전 및 치안  숙박/교통 등 관광편리성   기타
# 0   3.5         2.3      0.6            5.7  0.3
# 1   3.6         2.8      0.3            3.1  0.3
# 2   3.4         2.1      0.7            6.7  0.3
# 3   3.7         3.6      0.3            3.6  0.2
# 4   3.3         1.4      0.5            2.2  0.5

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           }
consider_2020 = consider_2020.rename(columns = columns)
consider_2020.head()
# Out:
#      분류    세부분류   사례수  자연경관 감상  휴양/휴식  역사/문화유적/전통문화 체험  음식/미식 탐방   쇼핑  여행비용  \
# 0  [전체]     NaN  3483     43.5   34.3              0.8       8.6  0.5   3.5
# 1    구분  01-02월   928     56.0   27.4              0.9       5.6  0.0   3.6
# 2    구분  08-12월  2555     38.9   36.8              0.8       9.7  0.6   3.4
# 3    월별     01월   602     56.5   25.8              0.9       5.4  0.0   3.7
# 4    월별     02월   327     55.0   30.3              0.8       5.9  0.0   3.3
#
#    자국과의 이동 거리  안전 및 치안  숙박/교통 등 관광편리성   기타
# 0         2.3      0.6            5.7  0.3
# 1         2.8      0.3            3.1  0.3
# 2         2.1      0.7            6.7  0.3
# 3         3.6      0.3            3.6  0.2
# 4         1.4      0.5            2.2  0.5

# %%
consider_2020.set_index(consider_2020.columns[0], inplace=True)
new_index_name='분류'
drop_rows = ['거주지', '여행 목적', '여행형태', '방문횟수', '이용 교통수단']
consider_2020_= consider_2020.drop(drop_rows)
consider_2020_.head()
# Out:
#         세부분류   사례수  자연경관 감상  휴양/휴식  역사/문화유적/전통문화 체험  음식/미식 탐방   쇼핑  여행비용  \
# 분류
# [전체]     NaN  3483     43.5   34.3              0.8       8.6  0.5   3.5
# 구분    01-02월   928     56.0   27.4              0.9       5.6  0.0   3.6
# 구분    08-12월  2555     38.9   36.8              0.8       9.7  0.6   3.4
# 월별       01월   602     56.5   25.8              0.9       5.4  0.0   3.7
# 월별       02월   327     55.0   30.3              0.8       5.9  0.0   3.3
#
#       자국과의 이동 거리  안전 및 치안  숙박/교통 등 관광편리성   기타
# 분류
# [전체]         2.3      0.6            5.7  0.3
# 구분           2.8      0.3            3.1  0.3
# 구분           2.1      0.7            6.7  0.3
# 월별           3.6      0.3            3.6  0.2
# 월별           1.4      0.5            2.2  0.5

# %% [markdown]
# ## 여행지 선정 시 비교국/도시
# - 해외나 다른 도시를 고려했는지를 나타냄

# %%
compare_2020 = pd.read_excel(DATA_PATH + '2020/05 여행목적지 선정 시 비교국,도시.xlsx',
                            skiprows=1,
                            skipfooter=1)
compare_2020.head()
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  처음부터 제주선택  해외여행 검토  국내 다른지역 검토
# 0       [전체]        NaN  3483       78.1      9.6        12.3
# 1         구분     01-02월   928       85.0     11.1         3.9
# 2         구분     08-12월  2555       75.6      9.1        15.3
# 3         월별        01월   602       82.3     12.9         4.8
# 4         월별        02월   327       90.1      7.7         2.2

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           }
compare_2020 = compare_2020.rename(columns = columns)
compare_2020.head()
# Out:
#      분류    세부분류   사례수  처음부터 제주선택  해외여행 검토  국내 다른지역 검토
# 0  [전체]     NaN  3483       78.1      9.6        12.3
# 1    구분  01-02월   928       85.0     11.1         3.9
# 2    구분  08-12월  2555       75.6      9.1        15.3
# 3    월별     01월   602       82.3     12.9         4.8
# 4    월별     02월   327       90.1      7.7         2.2

# %%
compare_2020.set_index(compare_2020.columns[0], inplace=True)
new_index_name='분류'
drop_rows = ['거주지', '여행 목적', '여행형태', '방문횟수', '이용 교통수단']
compare_2020_= compare_2020.drop(drop_rows)
compare_2020_.head()
# Out:
#         세부분류   사례수  처음부터 제주선택  해외여행 검토  국내 다른지역 검토
# 분류
# [전체]     NaN  3483       78.1      9.6        12.3
# 구분    01-02월   928       85.0     11.1         3.9
# 구분    08-12월  2555       75.6      9.1        15.3
# 월별       01월   602       82.3     12.9         4.8
# 월별       02월   327       90.1      7.7         2.2

# %% [markdown]
# ## 정보습득경로

# %%
info_2020 = pd.read_excel(DATA_PATH + '2020/06 제주여행정보 습득경로1순위.xlsx',
                            skiprows=1,
                            skipfooter=1)
info_2020.head()
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  한국의 인터넷 사이트/앱  자국 여행사(오프라인)  관광안내책자  \
# 0       [전체]        NaN  3483           64.4           1.2     2.1
# 1         구분     01-02월   928           74.4           0.7     1.0
# 2         구분     08-12월  2555           60.8           1.5     2.5
# 3         월별        01월   602           72.6           0.2     1.2
# 4         월별        02월   327           77.7           1.5     0.7
#
#    친지, 친구, 동료  현지 한국 공공기관 및 박람회  과거여행경험  주요 언론매체(TV, 라디오, 신문, 잡지 등)  항공사, 호텔  \
# 0        13.3               0.2    14.5                         1.5      0.7
# 1        10.5               0.2    11.4                         0.6      0.2
# 2        14.3               0.2    15.6                         1.8      0.8
# 3        12.1               0.2    12.0                         0.4      0.2
# 4         7.6               0.2    10.3                         1.0      0.2
#
#     기타  정보를 얻지 않음
# 0  0.4        1.8
# 1  0.1        0.8
# 2  0.4        2.1
# 3  0.0        1.0
# ...

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           }
info_2020 = info_2020.rename(columns = columns)
info_2020.head()
# Out:
#      분류    세부분류   사례수  한국의 인터넷 사이트/앱  자국 여행사(오프라인)  관광안내책자  친지, 친구, 동료  \
# 0  [전체]     NaN  3483           64.4           1.2     2.1        13.3
# 1    구분  01-02월   928           74.4           0.7     1.0        10.5
# 2    구분  08-12월  2555           60.8           1.5     2.5        14.3
# 3    월별     01월   602           72.6           0.2     1.2        12.1
# 4    월별     02월   327           77.7           1.5     0.7         7.6
#
#    현지 한국 공공기관 및 박람회  과거여행경험  주요 언론매체(TV, 라디오, 신문, 잡지 등)  항공사, 호텔   기타  \
# 0               0.2    14.5                         1.5      0.7  0.4
# 1               0.2    11.4                         0.6      0.2  0.1
# 2               0.2    15.6                         1.8      0.8  0.4
# 3               0.2    12.0                         0.4      0.2  0.0
# 4               0.2    10.3                         1.0      0.2  0.3
#
#    정보를 얻지 않음
# 0        1.8
# 1        0.8
# 2        2.1
# 3        1.0
# 4        0.5

# %%
info_2020.set_index(info_2020.columns[0], inplace=True)
new_index_name='분류'
drop_rows = ['거주지', '여행 목적', '여행형태', '방문횟수', '이용 교통수단']
info_2020_= info_2020.drop(drop_rows)
info_2020_.head()
# Out:
#         세부분류   사례수  한국의 인터넷 사이트/앱  자국 여행사(오프라인)  관광안내책자  친지, 친구, 동료  \
# 분류
# [전체]     NaN  3483           64.4           1.2     2.1        13.3
# 구분    01-02월   928           74.4           0.7     1.0        10.5
# 구분    08-12월  2555           60.8           1.5     2.5        14.3
# 월별       01월   602           72.6           0.2     1.2        12.1
# 월별       02월   327           77.7           1.5     0.7         7.6
#
#       현지 한국 공공기관 및 박람회  과거여행경험  주요 언론매체(TV, 라디오, 신문, 잡지 등)  항공사, 호텔   기타  \
# 분류
# [전체]               0.2    14.5                         1.5      0.7  0.4
# 구분                 0.2    11.4                         0.6      0.2  0.1
# 구분                 0.2    15.6                         1.8      0.8  0.4
# 월별                 0.2    12.0                         0.4      0.2  0.0
# 월별                 0.2    10.3                         1.0      0.2  0.3
#
#       정보를 얻지 않음
# 분류
# [전체]        1.8
# 구분          0.8
# 구분          2.1
# 월별          1.0
# ...

# %% [markdown]
# ## 인터넷 정보를 얻은 곳

# %%
interinfo_2020 = pd.read_excel(DATA_PATH + '2020/06-1 온라인 상 정보습득 1순위.xlsx',
                            skiprows=1,
                            skipfooter=1)
interinfo_2020.head()
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  포털사이트 검색(구글, 야후, 네이버 등)  \
# 0       [전체]        NaN  2817                     67.7
# 1         구분     01-02월   778                     75.2
# 2         구분     08-12월  2039                     64.8
# 3         월별        01월   498                     76.9
# 4         월별        02월   280                     72.3
#
#    여행전문사이트 또는 앱(트립어드바이저 등)  소셜미디어(블로그, 페이스북, 인스타그램, 웨이보 등)  동영상 사이트(유투브 등)  \
# 0                      3.5                            22.2             3.0
# 1                      1.7                            19.8             1.2
# 2                      4.2                            23.1             3.7
# 3                      1.6                            16.9             1.6
# 4                      1.8                            25.1             0.6
#
#    개별관광지 및 관광시설 홈페이지  여행사 홈페이지  공공기관사이트(문화체육관광부, 제주특별자치도 등)   기타
# 0                1.9       0.5                          0.9  0.3
# ...

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '포털사이트 검색(구글, 야후, 네이버 등)' : '포털 검색',
           '여행전문사이트 또는 앱(트립어드바이저 등)' : '여행전문 사이트/앱',
           '소셜미디어(블로그, 페이스북, 인스타그램, 웨이보 등)' : '소셜미디어',
           '동영상 사이트(유투브 등)' : '동영상 사이트',
           '공공기관사이트(문화체육관광부, 제주특별자치도 등)' : '공공기관 사이트'
           }
interinfo_2020 = interinfo_2020.rename(columns = columns)
interinfo_2020.head()
# Out:
#      분류    세부분류   사례수  포털 검색  여행전문 사이트/앱  소셜미디어  동영상 사이트  개별관광지 및 관광시설 홈페이지  \
# 0  [전체]     NaN  2817   67.7         3.5   22.2      3.0                1.9
# 1    구분  01-02월   778   75.2         1.7   19.8      1.2                1.5
# 2    구분  08-12월  2039   64.8         4.2   23.1      3.7                2.1
# 3    월별     01월   498   76.9         1.6   16.9      1.6                2.2
# 4    월별     02월   280   72.3         1.8   25.1      0.6                0.3
#
#    여행사 홈페이지  공공기관 사이트   기타
# 0       0.5       0.9  0.3
# 1       0.2       0.0  0.3
# 2       0.6       1.3  0.2
# 3       0.3       0.0  0.5
# 4       0.0       0.0  0.0

# %%
interinfo_2020.set_index(interinfo_2020.columns[0], inplace=True)
new_index_name='분류'
drop_rows = ['거주지', '여행 목적', '여행형태', '방문횟수', '이용 교통수단']
interinfo_2020_= interinfo_2020.drop(drop_rows)
interinfo_2020_.head()
# Out:
#         세부분류   사례수  포털 검색  여행전문 사이트/앱  소셜미디어  동영상 사이트  개별관광지 및 관광시설 홈페이지  \
# 분류
# [전체]     NaN  2817   67.7         3.5   22.2      3.0                1.9
# 구분    01-02월   778   75.2         1.7   19.8      1.2                1.5
# 구분    08-12월  2039   64.8         4.2   23.1      3.7                2.1
# 월별       01월   498   76.9         1.6   16.9      1.6                2.2
# 월별       02월   280   72.3         1.8   25.1      0.6                0.3
#
#       여행사 홈페이지  공공기관 사이트   기타
# 분류
# [전체]       0.5       0.9  0.3
# 구분         0.2       0.0  0.3
# 구분         0.6       1.3  0.2
# 월별         0.3       0.0  0.5
# 월별         0.0       0.0  0.0

# %% [markdown]
# - 코로나 영향으로 인해 서서히 여행유튜브 채널이 뜨면서 영상 사이트에서 정보를 얻는 비율이 증가하기 시작

# %% [markdown]
# ## 필요한 정보 1순위

# %%
need_2020 = pd.read_excel(DATA_PATH + '2020/07 여행시 필요정보 1순위.xlsx',
                            skiprows=1,
                            skipfooter=1)
need_2020.head()
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  방문지 정보(개장시간, 입장료, 여행코스 등)  이동 거리 및 교통편  \
# 0       [전체]        NaN  3483                       27.5         21.9
# 1         구분     01-02월   928                       34.3         31.2
# 2         구분     08-12월  2555                       25.1         18.5
# 3         월별        01월   602                       37.1         31.3
# 4         월별        02월   327                       29.0         30.9
#
#    음식 및 맛집 정보  쇼핑 장소  숙박시설  지역 축제 및 행사정보  역사/문화유적/전통문화 체험 관련 정보  \
# 0        28.8    0.4  18.2           1.2                    1.4
# 1        21.7    0.9   8.5           1.8                    1.3
# 2        31.3    0.3  21.7           1.0                    1.4
# 3        17.9    1.0   9.0           1.6                    1.6
# 4        28.8    0.7   7.6           2.3                    0.7
#
#    금융 정보(ATM, 환전소 등)  무료 WI-FI   기타
# 0                0.0       0.2  0.3
# 1                0.0       0.0  0.3
# 2                0.1       0.3  0.3
# ...

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           }
need_2020 = need_2020.rename(columns = columns)
need_2020.head()
# Out:
#      분류    세부분류   사례수  방문지 정보(개장시간, 입장료, 여행코스 등)  이동 거리 및 교통편  음식 및 맛집 정보  \
# 0  [전체]     NaN  3483                       27.5         21.9        28.8
# 1    구분  01-02월   928                       34.3         31.2        21.7
# 2    구분  08-12월  2555                       25.1         18.5        31.3
# 3    월별     01월   602                       37.1         31.3        17.9
# 4    월별     02월   327                       29.0         30.9        28.8
#
#    쇼핑 장소  숙박시설  지역 축제 및 행사정보  역사/문화유적/전통문화 체험 관련 정보  금융 정보(ATM, 환전소 등)  \
# 0    0.4  18.2           1.2                    1.4                0.0
# 1    0.9   8.5           1.8                    1.3                0.0
# 2    0.3  21.7           1.0                    1.4                0.1
# 3    1.0   9.0           1.6                    1.6                0.0
# 4    0.7   7.6           2.3                    0.7                0.0
#
#    무료 WI-FI   기타
# 0       0.2  0.3
# 1       0.0  0.3
# 2       0.3  0.3
# 3       0.0  0.4
# ...

# %%
need_2020.set_index(need_2020.columns[0], inplace=True)
new_index_name='분류'
drop_rows = ['거주지', '여행 목적', '여행형태', '방문횟수', '이용 교통수단']
need_2020_= need_2020.drop(drop_rows)
need_2020_.head()
# Out:
#         세부분류   사례수  방문지 정보(개장시간, 입장료, 여행코스 등)  이동 거리 및 교통편  음식 및 맛집 정보  쇼핑 장소  \
# 분류
# [전체]     NaN  3483                       27.5         21.9        28.8    0.4
# 구분    01-02월   928                       34.3         31.2        21.7    0.9
# 구분    08-12월  2555                       25.1         18.5        31.3    0.3
# 월별       01월   602                       37.1         31.3        17.9    1.0
# 월별       02월   327                       29.0         30.9        28.8    0.7
#
#       숙박시설  지역 축제 및 행사정보  역사/문화유적/전통문화 체험 관련 정보  금융 정보(ATM, 환전소 등)  무료 WI-FI  \
# 분류
# [전체]  18.2           1.2                    1.4                0.0       0.2
# 구분     8.5           1.8                    1.3                0.0       0.0
# 구분    21.7           1.0                    1.4                0.1       0.3
# 월별     9.0           1.6                    1.6                0.0       0.0
# 월별     7.6           2.3                    0.7                0.0       0.0
#
#        기타
# 분류
# ...

# %% [markdown]
# ## 여행 동반자

# %%
companion_2020 = pd.read_excel(DATA_PATH + '2020/09 동반자유형.xlsx',
                            skiprows=1,
                            skipfooter=1)
companion_2020.head()
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  혼자왔음  가족/친지  친구/연인  직장동료   기타
# 0       [전체]        NaN  3483   6.4   55.6   37.1   6.3  0.2
# 1         구분     01-02월   928   5.8   40.4   43.5  11.6  0.3
# 2         구분     08-12월  2555   6.7   61.1   34.8   4.4  0.2
# 3         월별        01월   602   5.7   41.3   41.4  12.9  0.5
# 4         월별        02월   327   5.9   38.8   47.3   9.2  0.0

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '혼자왔음' : '혼자'
           }
companion_2020 = companion_2020.rename(columns = columns)
companion_2020.head()
# Out:
#      분류    세부분류   사례수   혼자  가족/친지  친구/연인  직장동료   기타
# 0  [전체]     NaN  3483  6.4   55.6   37.1   6.3  0.2
# 1    구분  01-02월   928  5.8   40.4   43.5  11.6  0.3
# 2    구분  08-12월  2555  6.7   61.1   34.8   4.4  0.2
# 3    월별     01월   602  5.7   41.3   41.4  12.9  0.5
# 4    월별     02월   327  5.9   38.8   47.3   9.2  0.0

# %%
companion_2020.set_index(companion_2020.columns[0], inplace=True)
new_index_name='분류'
drop_rows = ['거주지', '여행 목적', '여행형태', '방문횟수', '이용 교통수단']
companion_2020_= companion_2020.drop(drop_rows)
companion_2020_.head()
# Out:
#         세부분류   사례수   혼자  가족/친지  친구/연인  직장동료   기타
# 분류
# [전체]     NaN  3483  6.4   55.6   37.1   6.3  0.2
# 구분    01-02월   928  5.8   40.4   43.5  11.6  0.3
# 구분    08-12월  2555  6.7   61.1   34.8   4.4  0.2
# 월별       01월   602  5.7   41.3   41.4  12.9  0.5
# 월별       02월   327  5.9   38.8   47.3   9.2  0.0

# %% [markdown]
# ## 제주에 가서 한 활동
# - 중복 응답이 가능한 항목

# %%
activity_2020 = pd.read_excel(DATA_PATH + '2020/10 제주활동.xlsx',
                            skiprows=1,
                            skipfooter=1)
activity_2020.head()
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  자연경관감상  식도락(맛집여행)  산/오름/올레길 트레킹    쇼핑  \
# 0       [전체]        NaN  3483    90.3       98.4          56.5  86.6
# 1         구분     01-02월   928    97.8       97.9          57.7  93.8
# 2         구분     08-12월  2555    87.6       98.6          56.1  84.0
# 3         월별        01월   602    97.1       97.0          49.7  94.8
# 4         월별        02월   327    99.0       99.7          72.4  91.9
#
#    박물관/테마공원 방문  회의/업무/컨벤션/세미나  공연/축제/이벤트 참여  해변활동(해수욕 등)  유흥/오락/경마  전통문화체험  \
# 0         40.9            5.1           8.1         34.9       5.4     5.8
# 1         52.6            9.2          10.2         56.0       2.8     4.6
# 2         36.6            3.6           7.3         27.3       6.3     6.2
# 3         53.8           11.0           6.7         52.0       3.2     6.0
# 4         50.3            5.9          16.6         63.2       2.0     2.0
#
#    종교/순례활동  영화/드라마촬영지방문  역사/문화유적지방문  레포츠(승마, 골프, ATV 등)  미용(온천/스파/마사지)   기타
# ...

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           }
activity_2020 = activity_2020.rename(columns = columns)
activity_2020.head()
# Out:
#      분류    세부분류   사례수  자연경관감상  식도락(맛집여행)  산/오름/올레길 트레킹    쇼핑  박물관/테마공원 방문  \
# 0  [전체]     NaN  3483    90.3       98.4          56.5  86.6         40.9
# 1    구분  01-02월   928    97.8       97.9          57.7  93.8         52.6
# 2    구분  08-12월  2555    87.6       98.6          56.1  84.0         36.6
# 3    월별     01월   602    97.1       97.0          49.7  94.8         53.8
# 4    월별     02월   327    99.0       99.7          72.4  91.9         50.3
#
#    회의/업무/컨벤션/세미나  공연/축제/이벤트 참여  해변활동(해수욕 등)  유흥/오락/경마  전통문화체험  종교/순례활동  \
# 0            5.1           8.1         34.9       5.4     5.8      2.3
# 1            9.2          10.2         56.0       2.8     4.6      0.8
# 2            3.6           7.3         27.3       6.3     6.2      2.9
# 3           11.0           6.7         52.0       3.2     6.0      1.2
# 4            5.9          16.6         63.2       2.0     2.0      0.0
#
#    영화/드라마촬영지방문  역사/문화유적지방문  레포츠(승마, 골프, ATV 등)  미용(온천/스파/마사지)   기타
# ...

# %%
activity_2020.set_index(activity_2020.columns[0], inplace=True)
new_index_name='분류'
drop_rows = ['거주지', '여행 목적', '여행형태', '방문횟수', '이용 교통수단']
activity_2020_= activity_2020.drop(drop_rows)
activity_2020_.head()
# Out:
#         세부분류   사례수  자연경관감상  식도락(맛집여행)  산/오름/올레길 트레킹    쇼핑  박물관/테마공원 방문  \
# 분류
# [전체]     NaN  3483    90.3       98.4          56.5  86.6         40.9
# 구분    01-02월   928    97.8       97.9          57.7  93.8         52.6
# 구분    08-12월  2555    87.6       98.6          56.1  84.0         36.6
# 월별       01월   602    97.1       97.0          49.7  94.8         53.8
# 월별       02월   327    99.0       99.7          72.4  91.9         50.3
#
#       회의/업무/컨벤션/세미나  공연/축제/이벤트 참여  해변활동(해수욕 등)  유흥/오락/경마  전통문화체험  종교/순례활동  \
# 분류
# [전체]            5.1           8.1         34.9       5.4     5.8      2.3
# 구분              9.2          10.2         56.0       2.8     4.6      0.8
# 구분              3.6           7.3         27.3       6.3     6.2      2.9
# 월별             11.0           6.7         52.0       3.2     6.0      1.2
# 월별              5.9          16.6         63.2       2.0     2.0      0.0
#
#       영화/드라마촬영지방문  역사/문화유적지방문  레포츠(승마, 골프, ATV 등)  미용(온천/스파/마사지)   기타
# 분류
# ...

# %% [markdown]
# ## 가장 만족했던 활동 1순위

# %%
mostact_2020 = pd.read_excel(DATA_PATH + '2020/10-1 가장 만족한 활동 1위.xlsx',
                            skiprows=1,
                            skipfooter=1)
mostact_2020.head()
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  자연경관감상  식도락(맛집여행)  산/오름/올레길 트레킹   쇼핑  \
# 0       [전체]        NaN  3483    43.5       21.4          14.6  0.7
# 1         구분     01-02월   928    31.6       14.6          17.4  0.8
# 2         구분     08-12월  2555    47.8       23.8          13.6  0.7
# 3         월별        01월   602    33.4       15.6          14.7  1.1
# 4         월별        02월   327    28.4       12.9          22.2  0.2
#
#    박물관/테마공원 방문  회의/업무/컨벤션/세미나  공연/축제/이벤트 참여  해변활동(해수욕 등)  유흥/오락/경마  전통문화체험  \
# 0          7.3            0.9           1.0          4.6       0.4     0.1
# 1         16.8            1.5           2.9          6.7       0.3     0.0
# 2          3.9            0.7           0.3          3.8       0.4     0.1
# 3         17.9            1.3           1.1          6.7       0.4     0.0
# 4         14.7            1.9           6.2          6.8       0.0     0.0
#
#    종교/순례활동  영화/드라마촬영지방문  역사/문화유적지방문  레포츠(승마, 골프, ATV 등)  미용(온천/스파/마사지)   기타
# ...

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           }
mostact_2020 = mostact_2020.rename(columns = columns)
mostact_2020.head()
# Out:
#      분류    세부분류   사례수  자연경관감상  식도락(맛집여행)  산/오름/올레길 트레킹   쇼핑  박물관/테마공원 방문  \
# 0  [전체]     NaN  3483    43.5       21.4          14.6  0.7          7.3
# 1    구분  01-02월   928    31.6       14.6          17.4  0.8         16.8
# 2    구분  08-12월  2555    47.8       23.8          13.6  0.7          3.9
# 3    월별     01월   602    33.4       15.6          14.7  1.1         17.9
# 4    월별     02월   327    28.4       12.9          22.2  0.2         14.7
#
#    회의/업무/컨벤션/세미나  공연/축제/이벤트 참여  해변활동(해수욕 등)  유흥/오락/경마  전통문화체험  종교/순례활동  \
# 0            0.9           1.0          4.6       0.4     0.1      0.2
# 1            1.5           2.9          6.7       0.3     0.0      0.0
# 2            0.7           0.3          3.8       0.4     0.1      0.2
# 3            1.3           1.1          6.7       0.4     0.0      0.0
# 4            1.9           6.2          6.8       0.0     0.0      0.0
#
#    영화/드라마촬영지방문  역사/문화유적지방문  레포츠(승마, 골프, ATV 등)  미용(온천/스파/마사지)   기타
# ...

# %%
mostact_2020.set_index(mostact_2020.columns[0], inplace=True)
new_index_name='분류'
drop_rows = ['거주지', '여행 목적', '여행형태', '방문횟수', '이용 교통수단']
mostact_2020_= mostact_2020.drop(drop_rows)
mostact_2020_.head()
# Out:
#         세부분류   사례수  자연경관감상  식도락(맛집여행)  산/오름/올레길 트레킹   쇼핑  박물관/테마공원 방문  \
# 분류
# [전체]     NaN  3483    43.5       21.4          14.6  0.7          7.3
# 구분    01-02월   928    31.6       14.6          17.4  0.8         16.8
# 구분    08-12월  2555    47.8       23.8          13.6  0.7          3.9
# 월별       01월   602    33.4       15.6          14.7  1.1         17.9
# 월별       02월   327    28.4       12.9          22.2  0.2         14.7
#
#       회의/업무/컨벤션/세미나  공연/축제/이벤트 참여  해변활동(해수욕 등)  유흥/오락/경마  전통문화체험  종교/순례활동  \
# 분류
# [전체]            0.9           1.0          4.6       0.4     0.1      0.2
# 구분              1.5           2.9          6.7       0.3     0.0      0.0
# 구분              0.7           0.3          3.8       0.4     0.1      0.2
# 월별              1.3           1.1          6.7       0.4     0.0      0.0
# 월별              1.9           6.2          6.8       0.0     0.0      0.0
#
#       영화/드라마촬영지방문  역사/문화유적지방문  레포츠(승마, 골프, ATV 등)  미용(온천/스파/마사지)   기타
# 분류
# ...

# %% [markdown]
# ## 주 이용 숙박시설

# %%
accom_2020 = pd.read_excel(DATA_PATH + '2020/11 주 이용 숙박시설.xlsx',
                            skiprows=1,
                            skipfooter=1)
accom_2020.head()
# Out:
#   Unnamed: 0 Unnamed: 1   사례수    호텔   모텔  게스트하우스/호스텔    펜션  콘도/리조트  친척/친구집  \
# 0       [전체]        NaN  3483  53.5  2.4         6.3  14.7    13.3     3.5
# 1         구분     01-02월   928  53.2  3.6         6.5  17.0    10.5     0.2
# 2         구분     08-12월  2555  53.5  2.0         6.3  13.9    14.3     4.7
# 3         월별        01월   602  49.7  4.0         7.9  17.9     9.1     0.2
# 4         월별        02월   327  59.8  2.9         4.1  15.3    13.1     0.0
#
#    숙박하지 않음   기타
# 0      4.6  1.7
# 1      7.1  2.0
# 2      3.6  1.6
# 3      9.1  2.2
# 4      3.2  1.6

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           }
accom_2020 = accom_2020.rename(columns = columns)
accom_2020.head()
# Out:
#      분류    세부분류   사례수    호텔   모텔  게스트하우스/호스텔    펜션  콘도/리조트  친척/친구집  숙박하지 않음  \
# 0  [전체]     NaN  3483  53.5  2.4         6.3  14.7    13.3     3.5      4.6
# 1    구분  01-02월   928  53.2  3.6         6.5  17.0    10.5     0.2      7.1
# 2    구분  08-12월  2555  53.5  2.0         6.3  13.9    14.3     4.7      3.6
# 3    월별     01월   602  49.7  4.0         7.9  17.9     9.1     0.2      9.1
# 4    월별     02월   327  59.8  2.9         4.1  15.3    13.1     0.0      3.2
#
#     기타
# 0  1.7
# 1  2.0
# 2  1.6
# 3  2.2
# 4  1.6

# %%
accom_2020.set_index(accom_2020.columns[0], inplace=True)
new_index_name='분류'
drop_rows = ['거주지', '여행 목적', '여행형태', '방문횟수', '이용 교통수단']
accom_2020_= accom_2020.drop(drop_rows)
accom_2020_.head()
# Out:
#         세부분류   사례수    호텔   모텔  게스트하우스/호스텔    펜션  콘도/리조트  친척/친구집  숙박하지 않음   기타
# 분류
# [전체]     NaN  3483  53.5  2.4         6.3  14.7    13.3     3.5      4.6  1.7
# 구분    01-02월   928  53.2  3.6         6.5  17.0    10.5     0.2      7.1  2.0
# 구분    08-12월  2555  53.5  2.0         6.3  13.9    14.3     4.7      3.6  1.6
# 월별       01월   602  49.7  4.0         7.9  17.9     9.1     0.2      9.1  2.2
# 월별       02월   327  59.8  2.9         4.1  15.3    13.1     0.0      3.2  1.6

# %% [markdown]
# ## 주로 이용한 교통

# %%
traffic_2020 = pd.read_excel(DATA_PATH + '2020/12 이용 교통 수단.xlsx',
                            skiprows=1,
                            skipfooter=1)
traffic_2020.head()
# Out:
#   Unnamed: 0 Unnamed: 1   사례수   렌터카    버스    택시  전세버스(여행사제공)  시티투어버스  \
# 0       [전체]        NaN  3483  80.1  17.5  19.9          2.8     3.0
# 1         구분     01-02월   928  75.3  16.8  17.0          2.2     0.5
# 2         구분     08-12월  2555  81.9  17.8  20.9          3.0     4.0
# 3         월별        01월   602  69.2  20.6  22.3          3.3     0.4
# 4         월별        02월   327  86.7   9.9   7.3          0.1     0.5
#
#    자전거, 오토바이  친구 및 지인차량   기타
# 0        3.6        8.8  3.2
# 1        0.8        7.6  3.1
# 2        4.7        9.2  3.2
# 3        0.8        9.3  3.1
# 4        0.8        4.5  2.9

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           }
traffic_2020 = traffic_2020.rename(columns = columns)
traffic_2020.head()
# Out:
#      분류    세부분류   사례수   렌터카    버스    택시  전세버스(여행사제공)  시티투어버스  자전거, 오토바이  \
# 0  [전체]     NaN  3483  80.1  17.5  19.9          2.8     3.0        3.6
# 1    구분  01-02월   928  75.3  16.8  17.0          2.2     0.5        0.8
# 2    구분  08-12월  2555  81.9  17.8  20.9          3.0     4.0        4.7
# 3    월별     01월   602  69.2  20.6  22.3          3.3     0.4        0.8
# 4    월별     02월   327  86.7   9.9   7.3          0.1     0.5        0.8
#
#    친구 및 지인차량   기타
# 0        8.8  3.2
# 1        7.6  3.1
# 2        9.2  3.2
# 3        9.3  3.1
# 4        4.5  2.9

# %%
traffic_2020.set_index(traffic_2020.columns[0], inplace=True)
new_index_name='분류'
drop_rows = ['거주지', '여행 목적', '여행형태', '방문횟수', '이용 교통수단']
traffic_2020_= traffic_2020.drop(drop_rows)
traffic_2020_.head()
# Out:
#         세부분류   사례수   렌터카    버스    택시  전세버스(여행사제공)  시티투어버스  자전거, 오토바이  \
# 분류
# [전체]     NaN  3483  80.1  17.5  19.9          2.8     3.0        3.6
# 구분    01-02월   928  75.3  16.8  17.0          2.2     0.5        0.8
# 구분    08-12월  2555  81.9  17.8  20.9          3.0     4.0        4.7
# 월별       01월   602  69.2  20.6  22.3          3.3     0.4        0.8
# 월별       02월   327  86.7   9.9   7.3          0.1     0.5        0.8
#
#       친구 및 지인차량   기타
# 분류
# [전체]        8.8  3.2
# 구분          7.6  3.1
# 구분          9.2  3.2
# 월별          9.3  3.1
# 월별          4.5  2.9

# %% [markdown]
# ## 여행시 불만이었던 점

# %%
unsatis_2020 = pd.read_excel(DATA_PATH + '2020/17 제주여행 시 불만족 불편.xlsx',
                            skiprows=1,
                            skipfooter=1)
unsatis_2020.head()
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  여행정보를 얻기 어렵다  관광정보가 정확하지 않다  관광종사원이 불친절하다  \
# 0       [전체]        NaN  3483           5.0            6.6           6.3
# 1         구분     01-02월   928           2.8            2.3           4.4
# 2         구분     08-12월  2555           5.8            8.2           6.9
# 3         월별        01월   602           2.5            2.9           4.3
# 4         월별        02월   327           3.5            1.2           4.7
#
#    안내표지판이 부정확하다  식당과 음식이 불결하다  음식이 입에 맞지 않는다  물가가 비싸다  대중교통 이용이 불편하다  \
# 0           6.1           4.6            3.7     54.9           17.1
# 1           3.0           2.4            2.1     43.2           14.2
# 2           7.3           5.4            4.3     59.1           18.1
# 3           2.2           2.9            2.7     44.1           18.2
# 4           4.5           1.5            1.0     41.6            6.9
#
#    택시기사 서비스가 불편하다  관광가이드의 서비스가 좋지 않다  쇼핑품목이 다양하지 못하다  상품구입을 강요한다   기타  \
# ...

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '여행정보를 얻기 어렵다' : '접근성 낮은 여행정보',
           '관광정보가 정확하지 않다' : '부정확한 관광정보',
           '관광종사원이 불친절하다' : '불친절한 관광종사원',
           '안내표지판이 부정확하다' : '부정확한 안내',
           '식당과 음식이 불결하다' : '식당/음식의 위생',
           '음식이 입에 맞지 않는다' : '맞지 않는 음식',
           '물가가 비싸다' : '비싼 물가',
           '대중교통 이용이 불편하다' : '불편한 대중교통',
           '택시기사 서비스가 불편하다' : '불편한 택시기사 서비스',
           '관광가이드의 서비스가 좋지 않다' : '가이드의 안 좋은 서비스',
           '쇼핑품목이 다양하지 못하다' : '획일화된 쇼핑품목',
           '상품구입을 강요한다' : '상품구입 강요',
           '불만족하거나 불편했던 점이 없다' : '없음'
           }
unsatis_2020 = unsatis_2020.rename(columns = columns)
unsatis_2020.head()
# Out:
#      분류    세부분류   사례수  접근성 낮은 여행정보  부정확한 관광정보  불친절한 관광종사원  부정확한 안내  식당/음식의 위생  \
# 0  [전체]     NaN  3483          5.0        6.6         6.3      6.1        4.6
# 1    구분  01-02월   928          2.8        2.3         4.4      3.0        2.4
# 2    구분  08-12월  2555          5.8        8.2         6.9      7.3        5.4
# 3    월별     01월   602          2.5        2.9         4.3      2.2        2.9
# 4    월별     02월   327          3.5        1.2         4.7      4.5        1.5
#
#    맞지 않는 음식  비싼 물가  불편한 대중교통  불편한 택시기사 서비스  가이드의 안 좋은 서비스  획일화된 쇼핑품목  상품구입 강요  \
# 0       3.7   54.9      17.1           3.8            1.9       16.4      3.7
# 1       2.1   43.2      14.2           1.8            0.5        7.3      1.2
# 2       4.3   59.1      18.1           4.5            2.4       19.7      4.7
# 3       2.7   44.1      18.2           2.2            0.4        8.3      1.1
# 4       1.0   41.6       6.9           1.0            0.5        5.4      1.2
#
#     기타    없음
# 0  2.9  29.9
# ...

# %%
unsatis_2020.set_index(unsatis_2020.columns[0], inplace=True)
new_index_name='분류'
drop_rows = ['거주지', '여행 목적', '여행형태', '방문횟수', '이용 교통수단']
unsatis_2020_= unsatis_2020.drop(drop_rows)
unsatis_2020_.head()
# Out:
#         세부분류   사례수  접근성 낮은 여행정보  부정확한 관광정보  불친절한 관광종사원  부정확한 안내  식당/음식의 위생  \
# 분류
# [전체]     NaN  3483          5.0        6.6         6.3      6.1        4.6
# 구분    01-02월   928          2.8        2.3         4.4      3.0        2.4
# 구분    08-12월  2555          5.8        8.2         6.9      7.3        5.4
# 월별       01월   602          2.5        2.9         4.3      2.2        2.9
# 월별       02월   327          3.5        1.2         4.7      4.5        1.5
#
#       맞지 않는 음식  비싼 물가  불편한 대중교통  불편한 택시기사 서비스  가이드의 안 좋은 서비스  획일화된 쇼핑품목  \
# 분류
# [전체]       3.7   54.9      17.1           3.8            1.9       16.4
# 구분         2.1   43.2      14.2           1.8            0.5        7.3
# 구분         4.3   59.1      18.1           4.5            2.4       19.7
# 월별         2.7   44.1      18.2           2.2            0.4        8.3
# 월별         1.0   41.6       6.9           1.0            0.5        5.4
#
#       상품구입 강요   기타    없음
# 분류
# [전체]      3.7  2.9  29.9
# ...

# %% [markdown]
# ## 전반적인 만족도

# %%
satis_2020 = pd.read_excel(DATA_PATH + '2020/18 전반적 만족도.xlsx',
                            skiprows=1,
                            skipfooter=1)
satis_2020.head()
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족  BOT2(①+②)  \
# 0       [전체]        NaN  3483      1.0   1.3  15.4  65.2    17.1        2.3
# 1         구분     01-02월   928      0.0   0.4  10.8  71.4    17.4        0.4
# 2         구분     08-12월  2555      1.3   1.6  17.1  63.0    17.0        2.9
# 3         월별        01월   602      0.0   0.7  12.9  70.0    16.4        0.7
# 4         월별        02월   327      0.0   0.0   6.9  73.9    19.2        0.0
#
#    MID(③)  TOP2(④+⑤)  척도평균  100점평균
# 0    15.4       82.3  3.96   74.03
# 1    10.8       88.7  4.06   76.41
# 2    17.1       80.0  3.93   73.17
# 3    12.9       86.4  4.02   75.53
# 4     6.9       93.0  4.12   78.04

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '①매우 불만족' : '매우 불만족',
           '②불만족' : '불만족',
           '③보통' : '보통',
           '④만족' : '만족',
           '⑤매우 만족' : '매우 만족',
           'BOT2(①+②)' : '매우 불만족/불만족',
           'MID(③)' : '보통임',
           'TOP2(④+⑤)' : '만족/매우 만족'
           }
satis_2020 = satis_2020.rename(columns = columns)
satis_2020.head()
# Out:
#      분류    세부분류   사례수  매우 불만족  불만족    보통    만족  매우 만족  매우 불만족/불만족   보통임  \
# 0  [전체]     NaN  3483     1.0  1.3  15.4  65.2   17.1         2.3  15.4
# 1    구분  01-02월   928     0.0  0.4  10.8  71.4   17.4         0.4  10.8
# 2    구분  08-12월  2555     1.3  1.6  17.1  63.0   17.0         2.9  17.1
# 3    월별     01월   602     0.0  0.7  12.9  70.0   16.4         0.7  12.9
# 4    월별     02월   327     0.0  0.0   6.9  73.9   19.2         0.0   6.9
#
#    만족/매우 만족  척도평균  100점평균
# 0      82.3  3.96   74.03
# 1      88.7  4.06   76.41
# 2      80.0  3.93   73.17
# 3      86.4  4.02   75.53
# 4      93.0  4.12   78.04

# %%
satis_2020.set_index(satis_2020.columns[0], inplace=True)
new_index_name='분류'
drop_rows = ['거주지', '여행 목적', '여행형태', '방문횟수', '이용 교통수단']
satis_2020_= satis_2020.drop(drop_rows)
satis_2020_.head()
# Out:
#         세부분류   사례수  매우 불만족  불만족    보통    만족  매우 만족  매우 불만족/불만족   보통임  \
# 분류
# [전체]     NaN  3483     1.0  1.3  15.4  65.2   17.1         2.3  15.4
# 구분    01-02월   928     0.0  0.4  10.8  71.4   17.4         0.4  10.8
# 구분    08-12월  2555     1.3  1.6  17.1  63.0   17.0         2.9  17.1
# 월별       01월   602     0.0  0.7  12.9  70.0   16.4         0.7  12.9
# 월별       02월   327     0.0  0.0   6.9  73.9   19.2         0.0   6.9
#
#       만족/매우 만족  척도평균  100점평균
# 분류
# [전체]      82.3  3.96   74.03
# 구분        88.7  4.06   76.41
# 구분        80.0  3.93   73.17
# 월별        86.4  4.02   75.53
# 월별        93.0  4.12   78.04

# %% [markdown]
# ## 여행경비 평가
# - 여행 평가 중에 교통과 더불어 항상 매년 낮은 점수를 기록하는중
# - 18-19년도까지는 평가항목중에 만족도가 낮은 편이었어도 심하게 낮지는 않았는데, 2020년을 기점으로 서서히 여행경비 불만족도가 높아지기 시작함

# %%
fee_2020 = pd.read_excel(DATA_PATH + '2020/19-11 여행경비 만족도 평가.xlsx',
                            skiprows=1,
                            skipfooter=1)
fee_2020.head()
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 불만족  ②불만족   ③보통   ④만족  ⑤매우 만족  BOT2(①+②)  \
# 0       [전체]        NaN  3444      8.7  26.5  35.6  22.8     6.4       35.2
# 1         구분     01-02월   927      4.3  14.8  36.9  33.9    10.1       19.1
# 2         구분     08-12월  2518     10.3  30.8  35.1  18.7     5.1       41.1
# 3         월별        01월   600      4.7  16.9  37.2  31.0    10.2       21.6
# 4         월별        02월   327      3.5  10.9  36.3  39.3    10.0       14.4
#
#    MID(③)  TOP2(④+⑤)  척도평균  100점평균
# 0    35.6       29.2  2.92   47.97
# 1    36.9       44.1  3.31   57.71
# 2    35.1       23.8  2.78   44.38
# 3    37.2       41.2  3.25   56.26
# 4    36.3       49.4  3.42   60.39

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '①매우 불만족' : '매우 불만족',
           '②불만족' : '불만족',
           '③보통' : '보통',
           '④만족' : '만족',
           '⑤매우 만족' : '매우 만족',
           'BOT2(①+②)' : '매우 불만족/불만족',
           'MID(③)' : '보통임',
           'TOP2(④+⑤)' : '만족/매우 만족'
           }
fee_2020 = fee_2020.rename(columns = columns)
fee_2020.head()
# Out:
#      분류    세부분류   사례수  매우 불만족   불만족    보통    만족  매우 만족  매우 불만족/불만족   보통임  \
# 0  [전체]     NaN  3444     8.7  26.5  35.6  22.8    6.4        35.2  35.6
# 1    구분  01-02월   927     4.3  14.8  36.9  33.9   10.1        19.1  36.9
# 2    구분  08-12월  2518    10.3  30.8  35.1  18.7    5.1        41.1  35.1
# 3    월별     01월   600     4.7  16.9  37.2  31.0   10.2        21.6  37.2
# 4    월별     02월   327     3.5  10.9  36.3  39.3   10.0        14.4  36.3
#
#    만족/매우 만족  척도평균  100점평균
# 0      29.2  2.92   47.97
# 1      44.1  3.31   57.71
# 2      23.8  2.78   44.38
# 3      41.2  3.25   56.26
# 4      49.4  3.42   60.39

# %%
fee_2020.set_index(fee_2020.columns[0], inplace=True)
new_index_name='분류'
drop_rows = ['거주지', '여행 목적', '여행형태', '방문횟수', '이용 교통수단']
fee_2020_= fee_2020.drop(drop_rows)
fee_2020_.head()
# Out:
#         세부분류   사례수  매우 불만족   불만족    보통    만족  매우 만족  매우 불만족/불만족   보통임  \
# 분류
# [전체]     NaN  3444     8.7  26.5  35.6  22.8    6.4        35.2  35.6
# 구분    01-02월   927     4.3  14.8  36.9  33.9   10.1        19.1  36.9
# 구분    08-12월  2518    10.3  30.8  35.1  18.7    5.1        41.1  35.1
# 월별       01월   600     4.7  16.9  37.2  31.0   10.2        21.6  37.2
# 월별       02월   327     3.5  10.9  36.3  39.3   10.0        14.4  36.3
#
#       만족/매우 만족  척도평균  100점평균
# 분류
# [전체]      29.2  2.92   47.97
# 구분        44.1  3.31   57.71
# 구분        23.8  2.78   44.38
# 월별        41.2  3.25   56.26
# 월별        49.4  3.42   60.39

# %% [markdown]
# ## 재방문의향

# %%
revisit_2020 = pd.read_excel(DATA_PATH + '2020/20 재방문의향.xlsx',
                            skiprows=1,
                            skipfooter=1)
revisit_2020.head()
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①전혀 그렇지 않다  ②그렇지 않다  ③보통  ④그렇다  ⑤매우 그렇다  \
# 0       [전체]        NaN  3483         0.3      1.0  7.9  53.1     37.6
# 1         구분     01-02월   928         0.1      0.4  4.9  67.6     27.0
# 2         구분     08-12월  2555         0.4      1.2  9.0  47.9     41.5
# 3         월별        01월   602         0.0      0.7  5.8  67.1     26.4
# 4         월별        02월   327         0.2      0.0  3.2  68.6     27.9
#
#    BOT2(①+②)  MID(③)  TOP2(④+⑤)  척도평균  100점평균
# 0        1.3     7.9       90.8  4.27   81.69
# 1        0.5     4.9       94.6  4.21   80.24
# 2        1.6     9.0       89.4  4.29   82.22
# 3        0.7     5.8       93.5  4.19   79.83
# 4        0.2     3.2       96.5  4.24   80.99

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '①전혀 그렇지 않다' : '전혀 없음',
           '②그렇지 않다' : '없음',
           '③보통' : '보통',
           '④그렇다' : '있음',
           '⑤매우 그렇다' : '매우 있음',
           'BOT2(①+②)' : '전혀 없음/없음',
           'MID(③)' : '보통임',
           'TOP2(④+⑤)' : '있음/매우 있음'
           }
revisit_2020 = revisit_2020.rename(columns = columns)
revisit_2020.head()
# Out:
#      분류    세부분류   사례수  전혀 없음   없음   보통    있음  매우 있음  전혀 없음/없음  보통임  있음/매우 있음  \
# 0  [전체]     NaN  3483    0.3  1.0  7.9  53.1   37.6       1.3  7.9      90.8
# 1    구분  01-02월   928    0.1  0.4  4.9  67.6   27.0       0.5  4.9      94.6
# 2    구분  08-12월  2555    0.4  1.2  9.0  47.9   41.5       1.6  9.0      89.4
# 3    월별     01월   602    0.0  0.7  5.8  67.1   26.4       0.7  5.8      93.5
# 4    월별     02월   327    0.2  0.0  3.2  68.6   27.9       0.2  3.2      96.5
#
#    척도평균  100점평균
# 0  4.27   81.69
# 1  4.21   80.24
# 2  4.29   82.22
# 3  4.19   79.83
# 4  4.24   80.99

# %%
revisit_2020.set_index(revisit_2020.columns[0], inplace=True)
new_index_name='분류'
drop_rows = ['거주지', '여행 목적', '여행형태', '방문횟수', '이용 교통수단']
revisit_2020_= revisit_2020.drop(drop_rows)
revisit_2020_.head()
# Out:
#         세부분류   사례수  전혀 없음   없음   보통    있음  매우 있음  전혀 없음/없음  보통임  있음/매우 있음  \
# 분류
# [전체]     NaN  3483    0.3  1.0  7.9  53.1   37.6       1.3  7.9      90.8
# 구분    01-02월   928    0.1  0.4  4.9  67.6   27.0       0.5  4.9      94.6
# 구분    08-12월  2555    0.4  1.2  9.0  47.9   41.5       1.6  9.0      89.4
# 월별       01월   602    0.0  0.7  5.8  67.1   26.4       0.7  5.8      93.5
# 월별       02월   327    0.2  0.0  3.2  68.6   27.9       0.2  3.2      96.5
#
#       척도평균  100점평균
# 분류
# [전체]  4.27   81.69
# 구분    4.21   80.24
# 구분    4.29   82.22
# 월별    4.19   79.83
# 월별    4.24   80.99

# %% [markdown]
# ## 타인에게 추천 의향

# %%
recom_2020 = pd.read_excel(DATA_PATH + '2020/21 타인추천의향.xlsx',
                            skiprows=1,
                            skipfooter=1)
recom_2020.head()
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①전혀 그렇지 않다  ②그렇지 않다   ③보통  ④그렇다  ⑤매우 그렇다  \
# 0       [전체]        NaN  3483        27.0     35.4  10.9  19.4      7.2
# 1         구분     01-02월   928         0.1      1.2   6.1  67.1     25.5
# 2         구분     08-12월  2555        36.8     47.8  12.7   2.1      0.5
# 3         월별        01월   602         0.0      1.6   6.9  66.7     24.8
# 4         월별        02월   327         0.2      0.5   4.7  67.9     26.7
#
#    BOT2(①+②)  MID(③)  TOP2(④+⑤)  척도평균  100점평균
# 0       62.4    10.9       26.6  2.44   36.08
# 1        1.3     6.1       92.6  4.17   79.18
# 2       84.7    12.7        2.7  1.82   20.43
# 3        1.6     6.9       91.5  4.15   78.70
# 4        0.7     4.7       94.6  4.20   80.07

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
            '①전혀 그렇지 않다' : '전혀 없음',
           '②그렇지 않다' : '없음',
           '③보통' : '보통',
           '④그렇다' : '있음',
           '⑤매우 그렇다' : '매우 있음',
           'BOT2(①+②)' : '전혀 없음/없음',
           'MID(③)' : '보통임',
           'TOP2(④+⑤)' : '있음/매우 있음'
           }
recom_2020 = recom_2020.rename(columns = columns)
recom_2020.head()
# Out:
#      분류    세부분류   사례수  전혀 없음    없음    보통    있음  매우 있음  전혀 없음/없음   보통임  \
# 0  [전체]     NaN  3483   27.0  35.4  10.9  19.4    7.2      62.4  10.9
# 1    구분  01-02월   928    0.1   1.2   6.1  67.1   25.5       1.3   6.1
# 2    구분  08-12월  2555   36.8  47.8  12.7   2.1    0.5      84.7  12.7
# 3    월별     01월   602    0.0   1.6   6.9  66.7   24.8       1.6   6.9
# 4    월별     02월   327    0.2   0.5   4.7  67.9   26.7       0.7   4.7
#
#    있음/매우 있음  척도평균  100점평균
# 0      26.6  2.44   36.08
# 1      92.6  4.17   79.18
# 2       2.7  1.82   20.43
# 3      91.5  4.15   78.70
# 4      94.6  4.20   80.07

# %%
recom_2020.set_index(recom_2020.columns[0], inplace=True)
new_index_name='분류'
drop_rows = ['거주지', '여행 목적', '여행형태', '방문횟수', '이용 교통수단']
recom_2020_= recom_2020.drop(drop_rows)
recom_2020_.head()
# Out:
#         세부분류   사례수  전혀 없음    없음    보통    있음  매우 있음  전혀 없음/없음   보통임  있음/매우 있음  \
# 분류
# [전체]     NaN  3483   27.0  35.4  10.9  19.4    7.2      62.4  10.9      26.6
# 구분    01-02월   928    0.1   1.2   6.1  67.1   25.5       1.3   6.1      92.6
# 구분    08-12월  2555   36.8  47.8  12.7   2.1    0.5      84.7  12.7       2.7
# 월별       01월   602    0.0   1.6   6.9  66.7   24.8       1.6   6.9      91.5
# 월별       02월   327    0.2   0.5   4.7  67.9   26.7       0.7   4.7      94.6
#
#       척도평균  100점평균
# 분류
# [전체]  2.44   36.08
# 구분    4.17   79.18
# 구분    1.82   20.43
# 월별    4.15   78.70
# 월별    4.20   80.07

# %% [markdown]
# - 갑자기 예년에 비해 2월 이후부터는 타인 추천 의향이 엄청나게 추락하기 시작함. 코로나 영향?

# %% [markdown]
# ## 제주도 여행 전 이미지

# %%
image_bf_2020 = pd.read_excel(DATA_PATH + '2020/22-1 이미지여행전.xlsx',
                            skiprows=1,
                            skipfooter=1)
image_bf_2020.head()
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 나빴다  ②나빴다   ③보통  ④좋았다  ⑤매우 좋았다  BOT2(①+②)  \
# 0       [전체]        NaN  3483      0.2   0.7  20.1  61.1     17.9        0.9
# 1         구분     01-02월   928      0.0   0.1  14.2  67.1     18.6        0.1
# 2         구분     08-12월  2555      0.2   1.0  22.3  58.9     17.6        1.2
# 3         월별        01월   602      0.0   0.0  16.2  64.9     18.9        0.0
# 4         월별        02월   327      0.0   0.2  10.5  71.2     18.1        0.2
#
#    MID(③)  TOP2(④+⑤)  척도평균  100점평균
# 0    20.1       79.0  3.96   73.97
# 1    14.2       85.7  4.04   76.07
# 2    22.3       76.6  3.93   73.21
# 3    16.2       83.8  4.03   75.68
# 4    10.5       89.3  4.07   76.79

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '①매우 나빴다' : '매우 나빴음',
           '②나빴다' : '나빴음',
           '③보통' : '보통',
           '④좋았다' : '좋았음',
           '⑤매우 좋았다' : '매우 좋았음',
           'BOT2(①+②)' : '매우 나빴음/나빴음',
           'MID(③)' : '보통이었음',
           'TOP2(④+⑤)' : '좋았음/매우 좋았음'
           }
image_bf_2020 = image_bf_2020.rename(columns = columns)
image_bf_2020.head()
# Out:
#      분류    세부분류   사례수  매우 나빴음  나빴음    보통   좋았음  매우 좋았음  매우 나빴음/나빴음  보통이었음  \
# 0  [전체]     NaN  3483     0.2  0.7  20.1  61.1    17.9         0.9   20.1
# 1    구분  01-02월   928     0.0  0.1  14.2  67.1    18.6         0.1   14.2
# 2    구분  08-12월  2555     0.2  1.0  22.3  58.9    17.6         1.2   22.3
# 3    월별     01월   602     0.0  0.0  16.2  64.9    18.9         0.0   16.2
# 4    월별     02월   327     0.0  0.2  10.5  71.2    18.1         0.2   10.5
#
#    좋았음/매우 좋았음  척도평균  100점평균
# 0        79.0  3.96   73.97
# 1        85.7  4.04   76.07
# 2        76.6  3.93   73.21
# 3        83.8  4.03   75.68
# 4        89.3  4.07   76.79

# %%
image_bf_2020.set_index(image_bf_2020.columns[0], inplace=True)
new_index_name='분류'
drop_rows = ['거주지', '여행 목적', '여행형태', '방문횟수', '이용 교통수단']
image_bf_2020_= image_bf_2020.drop(drop_rows)
image_bf_2020_.head()
# Out:
#         세부분류   사례수  매우 나빴음  나빴음    보통   좋았음  매우 좋았음  매우 나빴음/나빴음  보통이었음  \
# 분류
# [전체]     NaN  3483     0.2  0.7  20.1  61.1    17.9         0.9   20.1
# 구분    01-02월   928     0.0  0.1  14.2  67.1    18.6         0.1   14.2
# 구분    08-12월  2555     0.2  1.0  22.3  58.9    17.6         1.2   22.3
# 월별       01월   602     0.0  0.0  16.2  64.9    18.9         0.0   16.2
# 월별       02월   327     0.0  0.2  10.5  71.2    18.1         0.2   10.5
#
#       좋았음/매우 좋았음  척도평균  100점평균
# 분류
# [전체]        79.0  3.96   73.97
# 구분          85.7  4.04   76.07
# 구분          76.6  3.93   73.21
# 월별          83.8  4.03   75.68
# 월별          89.3  4.07   76.79

# %% [markdown]
# ## 제주도 여행 후 이미지

# %%
image_af_2020 = pd.read_excel(DATA_PATH + '2020/22-2 이미지여행후.xlsx',
                            skiprows=1,
                            skipfooter=1)
image_af_2020.head()
# Out:
#   Unnamed: 0 Unnamed: 1   사례수  ①매우 나빠졌다  ②나빠졌다   ③보통  ④좋아졌다  ⑤매우 좋아졌다  \
# 0       [전체]        NaN  3483       0.5    1.7  17.8   55.4      24.7
# 1         구분     01-02월   928       0.0    0.3  12.8   63.3      23.7
# 2         구분     08-12월  2555       0.6    2.2  19.6   52.5      25.0
# 3         월별        01월   602       0.0    0.2  15.5   61.8      22.5
# 4         월별        02월   327       0.0    0.5   7.7   66.0      25.8
#
#    BOT2(①+②)  MID(③)  TOP2(④+⑤)  척도평균  100점평균
# 0        2.2    17.8       80.0  4.02   75.50
# 1        0.3    12.8       86.9  4.10   77.56
# 2        2.9    19.6       77.5  3.99   74.76
# 3        0.2    15.5       84.3  4.07   76.63
# 4        0.5     7.7       91.8  4.17   79.29

# %%
columns = {'Unnamed: 0' : '분류',
           'Unnamed: 1' : '세부분류',
           '①매우 나빠졌다' : '매우 나빠짐',
           '②나빠졌다' : '나빠짐',
           '③보통' :	'보통',
           '④좋아졌다' : '좋아짐',
           '⑤매우 좋아졌다' : '매우 좋아짐',
           'BOT2(①+②)' : '매우 나빠짐/나빠짐',
           'MID(③)' : '보통임',
           'TOP2(④+⑤)' : '좋아짐/매우 좋아짐'
           }
image_af_2020 = image_af_2020.rename(columns = columns)
image_af_2020.head()
# Out:
#      분류    세부분류   사례수  매우 나빠짐  나빠짐    보통   좋아짐  매우 좋아짐  매우 나빠짐/나빠짐   보통임  \
# 0  [전체]     NaN  3483     0.5  1.7  17.8  55.4    24.7         2.2  17.8
# 1    구분  01-02월   928     0.0  0.3  12.8  63.3    23.7         0.3  12.8
# 2    구분  08-12월  2555     0.6  2.2  19.6  52.5    25.0         2.9  19.6
# 3    월별     01월   602     0.0  0.2  15.5  61.8    22.5         0.2  15.5
# 4    월별     02월   327     0.0  0.5   7.7  66.0    25.8         0.5   7.7
#
#    좋아짐/매우 좋아짐  척도평균  100점평균
# 0        80.0  4.02   75.50
# 1        86.9  4.10   77.56
# 2        77.5  3.99   74.76
# 3        84.3  4.07   76.63
# 4        91.8  4.17   79.29

# %%
image_af_2020.set_index(image_af_2020.columns[0], inplace=True)
new_index_name='분류'
drop_rows = ['거주지', '여행 목적', '여행형태', '방문횟수', '이용 교통수단']
image_af_2020_= image_af_2020.drop(drop_rows)
image_af_2020_.head()
# Out:
#         세부분류   사례수  매우 나빠짐  나빠짐    보통   좋아짐  매우 좋아짐  매우 나빠짐/나빠짐   보통임  \
# 분류
# [전체]     NaN  3483     0.5  1.7  17.8  55.4    24.7         2.2  17.8
# 구분    01-02월   928     0.0  0.3  12.8  63.3    23.7         0.3  12.8
# 구분    08-12월  2555     0.6  2.2  19.6  52.5    25.0         2.9  19.6
# 월별       01월   602     0.0  0.2  15.5  61.8    22.5         0.2  15.5
# 월별       02월   327     0.0  0.5   7.7  66.0    25.8         0.5   7.7
#
#       좋아짐/매우 좋아짐  척도평균  100점평균
# 분류
# [전체]        80.0  4.02   75.50
# 구분          86.9  4.10   77.56
# 구분          77.5  3.99   74.76
# 월별          84.3  4.07   76.63
# 월별          91.8  4.17   79.29
